# %%
pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.7.0

# %%
import os
import math
import time
import inspect
from dataclasses import dataclass
import torch
import torch.nn as nn
from torch.nn import functional as F
import tiktoken
import numpy as np

# %%
import os
import math
import time
import inspect
from dataclasses import dataclass
import torch
import torch.nn as nn
from torch.nn import functional as F
# -----------------------------------------------------------------------------

device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    device = "mps"
print(f"using device: {device}")

def exit(discription="Debug Exit",exit=True):
    import sys
    print(discription)
    if exit==True:
        sys.exit(0)
# Out:
# using device: cuda

# %%
def load_tokens(filename):
    npt = np.load(filename)
    npt = npt.astype(np.int32) # added after video
    ptt = torch.tensor(npt, dtype=torch.long)
    return ptt

# %%
class DataLoaderLite:
    def __init__(self, B, T, process_rank, num_processes, split):
        self.B = B
        self.T = T
        self.process_rank = process_rank
        self.num_processes = num_processes
        assert split in {'train', 'val'}

        # get the shard filenames
        data_root = "/content/"
        shards = os.listdir(data_root)
        shards = [s for s in shards if split in s]
        shards = sorted(shards)
        shards = [os.path.join(data_root, s) for s in shards]
        self.shards = shards
        assert len(shards) > 0, f"no shards found for split {split}"
        if master_process:
            print(f"found {len(shards)} shards for split {split}")
        self.reset()

    def reset(self):
        # state, init at shard zero
        self.current_shard = 0
        self.tokens = load_tokens(self.shards[self.current_shard])
        self.current_position = self.B * self.T * self.process_rank

    def next_batch(self):
        B, T = self.B, self.T
        buf = self.tokens[self.current_position : self.current_position+B*T+1]
        #if buf[:-1].numel() < 8 * 1024:
        padding_size = 8 * 1024 - buf[:-1].numel()
        x = torch.cat([buf[:-1], torch.zeros(padding_size, dtype=buf[:-1].dtype)]).view(8, 1024)
        y = torch.cat([buf[1:], torch.zeros(padding_size, dtype=buf[1:].dtype)]).view(8, 1024)
        '''else:
            x = (buf[:-1]).view(B, T) # inputs
            y = (buf[1:]).view(B, T) # targets'''

        # advance the position in the tensor
        self.current_position += B * T * self.num_processes
        # if loading the next batch would be out of bounds, advance to next shard
        if self.current_position + (B * T * self.num_processes + 1) > len(self.tokens):
            self.current_shard = (self.current_shard + 1) % len(self.shards)
            self.tokens = load_tokens(self.shards[self.current_shard])
            self.current_position = B * T * self.process_rank

        return x, y

# %%
class CausalSelfAttention(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1
        # regularization
        self.n_head = config.n_head
        self.n_embd = config.n_embd

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)
        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        # nh is "number of heads", hs is "head size", and C (number of channels) = nh * hs
        # e.g. in GPT-2 (124M), n_head=12, hs=64, so nh*hs=C=768 channels in the Transformer
        qkv = self.c_attn(x)
        q, k, v = qkv.split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        y = F.scaled_dot_product_attention(q, k, v, is_causal=True) # flash attention
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side
        # output projection
        y = self.c_proj(y)
        return y

class MLP(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd)
        self.gelu    = nn.GELU(approximate='tanh')
        self.c_proj  = nn.Linear(4 * config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        return x

class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(config.n_embd)
        self.attn = CausalSelfAttention(config)
        self.ln_2 = nn.LayerNorm(config.n_embd)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

# %%
@dataclass
class GPTConfig:
    block_size: int = 1024 # max sequence length
    vocab_size: int = 50257 # number of tokens: 50,000 BPE merges + 256 bytes tokens + 1 <|endoftext|> token
    n_layer: int = 12 # number of layers
    n_head: int = 12 # number of heads
    n_embd: int = 768 # embedding dimension

# %%
class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.config = config

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = nn.LayerNorm(config.n_embd),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

        # weight sharing scheme
        self.transformer.wte.weight = self.lm_head.weight

        # init params
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            std = 0.02
            if hasattr(module, 'NANOGPT_SCALE_INIT'):
                std *= (2 * self.config.n_layer) ** -0.5
            torch.nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        # idx is of shape (B, T)
        B, T = idx.size()
        assert T <= self.config.block_size, f"Cannot forward sequence of length {T}, block size is only {self.config.block_size}"
        # forward the token and posisition embeddings
        pos = torch.arange(0, T, dtype=torch.long, device=idx.device) # shape (T)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (T, n_embd)
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (B, T, n_embd)
        x = tok_emb + pos_emb
        # forward the blocks of the transformer
        for block in self.transformer.h:
            x = block(x)
        # forward the final layernorm and the classifier
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x) # (B, T, vocab_size)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
        return logits, loss


    def configure_optimizers(self, weight_decay, learning_rate, device_type):
        # start with all of the candidate parameters (that require grad)
        param_dict = {pn: p for pn, p in self.named_parameters()}
        param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
        # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
        # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
        decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
        nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
        optim_groups = [
            {'params': decay_params, 'weight_decay': weight_decay},
            {'params': nodecay_params, 'weight_decay': 0.0}
        ]
        num_decay_params = sum(p.numel() for p in decay_params)
        num_nodecay_params = sum(p.numel() for p in nodecay_params)
        if master_process:
            print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
            print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
        # Create AdamW optimizer and use the fused version if it is available
        fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
        use_fused = fused_available and device_type == "cuda"
        if master_process:
            print(f"using fused AdamW: {use_fused}")
        optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=(0.9, 0.95), eps=1e-8, fused=use_fused)
        return optimizer

# %%
# -----------------------------------------------------------------------------
# helper function for HellaSwag eval
# takes tokens, mask, and logits, returns the index of the completion with the lowest loss

def get_most_likely_row(tokens, mask, logits):
    # evaluate the autoregressive loss at all positions
    shift_logits = (logits[..., :-1, :]).contiguous()
    shift_tokens = (tokens[..., 1:]).contiguous()
    flat_shift_logits = shift_logits.view(-1, shift_logits.size(-1))
    flat_shift_tokens = shift_tokens.view(-1)
    shift_losses = F.cross_entropy(flat_shift_logits, flat_shift_tokens, reduction='none')
    shift_losses = shift_losses.view(tokens.size(0), -1)
    # now get the average loss just for the completion region (where mask == 1), in each row
    shift_mask = (mask[..., 1:]).contiguous() # we must shift mask, so we start at the last prompt token
    masked_shift_losses = shift_losses * shift_mask
    # sum and divide by the number of 1s in the mask
    sum_loss = masked_shift_losses.sum(dim=1)
    avg_loss = sum_loss / shift_mask.sum(dim=1)
    # now we have a loss for each of the 4 completions
    # the one with the lowest loss should be the most likely
    pred_norm = avg_loss.argmin().item()
    return pred_norm

# %%
# -----------------------------------------------------------------------------
# simple launch:
# python train_gpt2.py
# DDP launch for e.g. 8 GPUs:
# torchrun --standalone --nproc_per_node=8 train_gpt2.py

# run the training loop
from torch.distributed import init_process_group, destroy_process_group
from torch.nn.parallel import DistributedDataParallel as DDP
import torch.distributed as dist

# set up DDP (distributed data parallel).
# torchrun command sets the env variables RANK, LOCAL_RANK, and WORLD_SIZE
ddp = int(os.environ.get('RANK', -1)) != -1 # is this a ddp run?
if ddp:
    # use of DDP atm demands CUDA, we set the device appropriately according to rank
    assert torch.cuda.is_available(), "for now i think we need CUDA for DDP"
    init_process_group(backend='nccl')
    ddp_rank = int(os.environ['RANK'])
    ddp_local_rank = int(os.environ['LOCAL_RANK'])
    ddp_world_size = int(os.environ['WORLD_SIZE'])
    device = f'cuda:{ddp_local_rank}'
    torch.cuda.set_device(device)
    master_process = ddp_rank == 0 # this process will do logging, checkpointing etc.
else:
    # vanilla, non-DDP run
    ddp_rank = 0
    ddp_local_rank = 0
    ddp_world_size = 1
    master_process = True
    # attempt to autodetect device
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda"
    elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
        device = "mps"
    print(f"using device: {device}")

# added after video, pytorch can be serious about it's device vs. device_type distinction
device_type = "cuda" if device.startswith("cuda") else "cpu"

torch.manual_seed(1337)
if torch.cuda.is_available():
    torch.cuda.manual_seed(1337)

enc = tiktoken.get_encoding("gpt2")

total_batch_size = 8192 # 2**19, ~0.5M, in number of tokens
B = 8 # micro batch size
T = 1024 # sequence length
assert total_batch_size % (B * T * ddp_world_size) == 0, "make sure total_batch_size is divisible by B * T * ddp_world_size"
grad_accum_steps = total_batch_size // (B * T * ddp_world_size)
if master_process:
    print(f"total desired batch size: {total_batch_size}")
    print(f"=> calculated gradient accumulation steps: {grad_accum_steps}")
# Out:
# using device: cuda
# total desired batch size: 8192
# => calculated gradient accumulation steps: 1

# %%
B * T * ddp_world_size
# Out:
# 8192

# %%
import re

def clean_text(text):
    # Remove special tokens using regex
    cleaned_text = re.sub(r'\[CLS\]|\[SEP\]|\<unk\>', '', text)
    # Remove multiple spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text

# %%
train_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, split="train")
val_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, split="val")

torch.set_float32_matmul_precision('high')

# create model
model = GPT(GPTConfig(vocab_size=50304))
# model = GPT.from_pretrained("gpt2") # or init from OpenAI GPT-2
model.to(device)
use_compile = False # torch.compile interferes with HellaSwag eval and Generation. TODO fix
if use_compile:
    model = torch.compile(model)
if ddp:
    model = DDP(model, device_ids=[ddp_local_rank])
raw_model = model.module if ddp else model # always contains the "raw" unwrapped model

max_lr = 6e-4
min_lr = max_lr * 0.1
warmup_steps = 715
max_steps = 19073 # 19,073 steps is ~1 epoch, if data is 10B tokens and batch size 0.5M tokens
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_steps:
        return max_lr * (it+1) / warmup_steps
    # 2) if it > lr_decay_iters, return min learning rate
    if it > max_steps:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_steps) / (max_steps - warmup_steps)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff starts at 1 and goes to 0
    return min_lr + coeff * (max_lr - min_lr)

# optimize!
optimizer = raw_model.configure_optimizers(weight_decay=0.1, learning_rate=6e-4, device_type=device_type)

# create the log directory we will write checkpoints to and log to
log_dir = "log"
os.makedirs(log_dir, exist_ok=True)
log_file = os.path.join(log_dir, f"log.txt")
enc = AutoTokenizer.from_pretrained('bolbolzaban/gpt2-persian')

with open(log_file, "w") as f: # open for writing to clear the file
    pass

for step in range(max_steps):
    t0 = time.time()
    last_step = (step == max_steps - 1)

    # once in a while evaluate our validation loss
    if step % 250 == 0 or last_step:
        model.eval()
        val_loader.reset()
        with torch.no_grad():
            val_loss_accum = 0.0
            val_loss_steps = 20
            for _ in range(val_loss_steps):
                x, y = val_loader.next_batch()
                x, y = x.to(device), y.to(device)
                with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
                    logits, loss = model(x, y)
                loss = loss / val_loss_steps
                val_loss_accum += loss.detach()
        if ddp:
            dist.all_reduce(val_loss_accum, op=dist.ReduceOp.AVG)
        if master_process:
            print(f"validation loss: {val_loss_accum.item():.4f}")
            with open(log_file, "a") as f:
                f.write(f"{step} val {val_loss_accum.item():.4f}\n")
            if step > 0 and (step % 5000 == 0 or last_step):
                # optionally write model checkpoints
                checkpoint_path = os.path.join(log_dir, f"model_{step:05d}.pt")
                checkpoint = {
                    'model': raw_model.state_dict(),
                    'config': raw_model.config,
                    'step': step,
                    'val_loss': val_loss_accum.item()
                }
                # you might also want to add optimizer.state_dict() and
                # rng seeds etc., if you wanted to more exactly resume training
                torch.save(checkpoint, checkpoint_path)

    # once in a while generate from the model (except step 0, which is noise)
    if ((step > 0 and step % 150 == 0) or last_step) and (not use_compile):
        model.eval()
        num_return_sequences = 4
        max_length = 60
        tokens = enc.encode("من آن مرغ غزل خوانم['BOM']")
        tokens = torch.tensor(tokens, dtype=torch.long)
        tokens = tokens.unsqueeze(0).repeat(num_return_sequences, 1)
        xgen = tokens.to(device)
        sample_rng = torch.Generator(device=device)
        sample_rng.manual_seed(42 + ddp_rank)
        while xgen.size(1) < max_length:
            # forward the model to get the logits
            with torch.no_grad():
                with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
                    logits, loss = model(xgen) # (B, T, vocab_size)
                # take the logits at the last position
                logits = logits[:, -1, :] # (B, vocab_size)
                # get the probabilities
                probs = F.softmax(logits, dim=-1)
                # do top-k sampling of 50 (huggingface pipeline default)
                # topk_probs here becomes (5, 50), topk_indices is (5, 50)
                topk_probs, topk_indices = torch.topk(probs, 50, dim=-1)
                # select a token from the top-k probabilities
                # note: multinomial does not demand the input to sum to 1
                ix = torch.multinomial(topk_probs, 1, generator=sample_rng) # (B, 1)
                # gather the corresponding indices
                xcol = torch.gather(topk_indices, -1, ix) # (B, 1)
                # append to the sequence
                xgen = torch.cat((xgen, xcol), dim=1)
        # print the generated text
        for i in range(num_return_sequences):
            tokens = xgen[i, :max_length].tolist()
            decoded = enc.decode(tokens)
            print(f"rank {ddp_rank} sample {i}: {clean_text(decoded)}")

    # do one step of the optimization
    model.train()
    optimizer.zero_grad()
    loss_accum = 0.0
    for micro_step in range(grad_accum_steps):
        x, y = train_loader.next_batch()
        x, y = x.to(device), y.to(device)
        # added after video, this field is also used by the forward pass.
        if ddp:
            model.require_backward_grad_sync = (micro_step == grad_accum_steps - 1)
        with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
            logits, loss = model(x, y)
        # we have to scale the loss to account for gradient accumulation,
        # because the gradients just add on each successive backward().
        # addition of gradients corresponds to a SUM in the objective, but
        # instead of a SUM we want MEAN. Scale the loss here so it comes out right
        loss = loss / grad_accum_steps
        loss_accum += loss.detach()
        loss.backward()
    if ddp:
        dist.all_reduce(loss_accum, op=dist.ReduceOp.AVG)
    norm = torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    # determine and set the learning rate for this iteration
    lr = get_lr(step)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    optimizer.step()
    if device_type == "cuda":
        torch.cuda.synchronize() # wait for the GPU to finish work
    t1 = time.time()
    dt = t1 - t0 # time difference in seconds
    tokens_processed = train_loader.B * train_loader.T * grad_accum_steps * ddp_world_size
    tokens_per_sec = tokens_processed / dt
    if master_process:
        print(f"step {step:5d} | loss: {loss_accum.item():.6f} | lr {lr:.4e} | norm: {norm:.4f} | dt: {dt*1000:.2f}ms | tok/sec: {tokens_per_sec:.2f}")
        with open(log_file, "a") as f:
            f.write(f"{step} train {loss_accum.item():.6f}\n")

if ddp:
    destroy_process_group()
# Out:
# found 1 shards for split train
# found 1 shards for split val
# num decayed parameter tensors: 50, with 124,354,560 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# using fused AdamW: True
# validation loss: 10.9340
# step     0 | loss: 10.908829 | lr 8.3916e-07 | norm: 26.5932 | dt: 22959.90ms | tok/sec: 356.80
# step     1 | loss: 10.818146 | lr 1.6783e-06 | norm: 25.9042 | dt: 2810.61ms | tok/sec: 2914.67
# step     2 | loss: 10.654526 | lr 2.5175e-06 | norm: 24.5189 | dt: 2827.45ms | tok/sec: 2897.31
# step     3 | loss: 10.464630 | lr 3.3566e-06 | norm: 21.5945 | dt: 2827.33ms | tok/sec: 2897.43
# step     4 | loss: 10.211823 | lr 4.1958e-06 | norm: 17.8052 | dt: 2841.54ms | tok/sec: 2882.94
# step     5 | loss: 9.995064 | lr 5.0350e-06 | norm: 14.3455 | dt: 2860.12ms | tok/sec: 2864.21
# step     6 | loss: 9.809555 | lr 5.8741e-06 | norm: 11.9406 | dt: 2867.53ms | tok/sec: 2856.81
# step     7 | loss: 9.634531 | lr 6.7133e-06 | norm: 9.7489 | dt: 2886.93ms | tok/sec: 2837.62
# step     8 | loss: 9.516071 | lr 7.5524e-06 | norm: 7.4874 | dt: 2907.39ms | tok/sec: 2817.65
# step     9 | loss: 9.406638 | lr 8.3916e-06 | norm: 6.8234 | dt: 2911.99ms | tok/sec: 2813.19
# step    10 | loss: 9.324224 | lr 9.2308e-06 | norm: 5.8939 | dt: 2929.88ms | tok/sec: 2796.02
# step    11 | loss: 9.243131 | lr 1.0070e-05 | norm: 4.9019 | dt: 2934.66ms | tok/sec: 2791.47
# step    12 | loss: 9.160789 | lr 1.0909e-05 | norm: 5.3741 | dt: 2956.79ms | tok/sec: 2770.57
# step    13 | loss: 9.089483 | lr 1.1748e-05 | norm: 5.1236 | dt: 2967.12ms | tok/sec: 2760.93
# step    14 | loss: 9.063099 | lr 1.2587e-05 | norm: 3.8518 | dt: 2978.42ms | tok/sec: 2750.45
# step    15 | loss: 9.029219 | lr 1.3427e-05 | norm: 3.9990 | dt: 2995.44ms | tok/sec: 2734.82
# step    16 | loss: 8.967102 | lr 1.4266e-05 | norm: 3.6307 | dt: 3020.54ms | tok/sec: 2712.10
# step    17 | loss: 8.964237 | lr 1.5105e-05 | norm: 3.4923 | dt: 3038.18ms | tok/sec: 2696.35
# step  3973 | loss: 0.046116 | lr 5.5911e-04 | norm: 0.6079 | dt: 3080.01ms | tok/sec: 2659.73
# step  3974 | loss: 0.045218 | lr 5.5909e-04 | norm: 0.6232 | dt: 3094.37ms | tok/sec: 2647.39
# step  3975 | loss: 0.038747 | lr 5.5906e-04 | norm: 0.6028 | dt: 3095.10ms | tok/sec: 2646.76
# step  3976 | loss: 0.039963 | lr 5.5904e-04 | norm: 0.6071 | dt: 3094.64ms | tok/sec: 2647.16

# %%
rank 0 sample 0: من آن مرغ غزل خوانم[BOM]
 [BOM] این بر[EOS]
  [BOM] از من شدم درو[EOS]
   [BOM] هم از تو که دل در[BOM] تو[BOM] و بی تو[EOS][BOM] باز[BOM] چون چون در هر چه و این این نه به که تو بر[EOS][BOM] در وی ها را[BOM][BOM] چون ز تو[BOM][BOM] ز تو از[EOS][BOM][BOM] چون سر چونش می و را[EOS][BOM] چون

# %%
# !pip install tiktoken
# !pip install datasets
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 requests-2.32.3 xxhash-3.4.1

# %%
import os
import multiprocessing as mp
import numpy as np
import tiktoken
from datasets import load_dataset # pip install datasets
from tqdm import tqdm # pip install tqdm
from transformers import pipeline, AutoTokenizer, GPT2LMHeadModel
from transformers import GemmaTokenizerFast


tokenizer = AutoTokenizer.from_pretrained('bolbolzaban/gpt2-persian')


def tokenize(doc):
    tokens = tokenizer.encode(doc, add_special_tokens=False)
    tokens_np = np.array(tokens)
    tokens_np_uint16 = tokens_np.astype(np.uint16)
    return tokens_np_uint16


def write_datafile(filename, tokens_np):
    np.save(filename, tokens_np)

# tokenize all documents and write output shards, each of shard_size tokens (last shard has remainder)
fp = open('/content/moulavi_norm.txt')
docs = fp.readlines()[2:]


fp = open('/content/feyz_norm.txt')
docs_feyz = fp.readlines()[2:]


fp = open('/content/bidel_norm.txt')
docs_bidel = fp.readlines()[2:]

fp = open('/content/ghaani_norm.txt')
docs_ghaani = fp.readlines()[2:]

docs = docs+docs_bidel+docs_ghaani+docs_feyz
print(len(docs))
lines = []
i=0
while i<len(docs)-1:
  mesr1 = docs[i].replace('\n', '')
  mesr2 = docs[i+1].replace('\n', '')
  if len(mesr1)==0:
     i+=1
     continue

  if len(mesr2)==0:
     i+=1
     continue
  line = '[BOM]'+ mesr1 + '[BOM]' + mesr2+ '[EOS]'
  lines.append(line)
  i+=2

print(len(lines))
docs = lines
docs = docs[:-3000]
nprocs = max(1, os.cpu_count()//2)
shard_size = int(1e8)

with mp.Pool(nprocs) as pool:
    shard_index = 1
    # preallocate buffer to hold current shard
    all_tokens_np = np.empty((shard_size,), dtype=np.uint16)
    token_count = 0
    progress_bar = None

    for tokens in pool.imap(tokenize, docs, chunksize=16):
      #print(tokens)
      if token_count + len(tokens) < shard_size:
            # simply append tokens to current shard
            all_tokens_np[token_count:token_count+len(tokens)] = tokens
            token_count += len(tokens)
            # update progress bar
            if progress_bar is None:
                progress_bar = tqdm(total=shard_size, unit="tokens", desc=f"Shard {shard_index}")
            progress_bar.update(len(tokens))
      else:
            # write the current shard and start a new one
            split = "val" if shard_index == 0 else "train"
            filename = f"a_hh_{split}_{shard_index:06d}"
            # split the document into whatever fits in this shard; the remainder goes to next one
            remainder = shard_size - token_count
            progress_bar.update(remainder)
            all_tokens_np[token_count:token_count+remainder] = tokens[:remainder]
            all_tokens_np = all_tokens_np[all_tokens_np!=0]
            write_datafile(filename, all_tokens_np)
            shard_index += 1
            progress_bar = None
            # populate the next shard with the leftovers of the current doc
            all_tokens_np[0:len(tokens)-remainder] = tokens[remainder:]
            token_count = len(tokens)-remainder

    # write any remaining tokens as the last shard
    if token_count != 0:
        split = "val" if shard_index == 0 else "train"
        filename = f"a_hh_{split}_{shard_index:06d}"
        all_tokens_np = all_tokens_np[:token_count]
        all_tokens_np = all_tokens_np[all_tokens_np!=0]
        write_datafile(filename, all_tokens_np[:token_count])
# Out:
# 78265
# 26394
# Shard 1:   0%|          | 0/100000000 [00:00<?, ?tokens/s]
# Shard 0:   0%|          | 53976/100000000 [00:19<10:16:57, 2699.99tokens/s]
#
# Shard 1:   0%|          | 24451/100000000 [00:00<14:41, 113411.88tokens/s]
# Shard 1:   0%|          | 37770/100000000 [00:00<13:39, 121942.52tokens/s]
# Shard 1:   0%|          | 50729/100000000 [00:00<13:23, 124466.06tokens/s]
# Shard 1:   0%|          | 63223/100000000 [00:00<13:54, 119727.87tokens/s]
# Shard 1:   0%|          | 76284/100000000 [00:00<13:34, 122673.56tokens/s]
# Shard 1:   0%|          | 88896/100000000 [00:00<13:29, 123382.78tokens/s]
# Shard 1:   0%|          | 102599/100000000 [00:00<13:09, 126557.86tokens/s]
# Shard 1:   0%|          | 116064/100000000 [00:00<13:08, 126692.91tokens/s]
# Shard 1:   0%|          | 128762/100000000 [00:01<14:03, 118354.97tokens/s]
# Shard 1:   0%|          | 140704/100000000 [00:01<14:12, 117105.54tokens/s]
# Shard 1:   0%|          | 154032/100000000 [00:01<13:40, 121729.30tokens/s]
# Shard 1:   0%|          | 167789/100000000 [00:01<13:11, 126165.00tokens/s]
# Shard 1:   0%|          | 180931/100000000 [00:01<13:04, 127297.97tokens/s]
# Shard 1:   0%|          | 193718/100000000 [00:01<13:29, 123316.60tokens/s]
# Shard 1:   0%|          | 207177/100000000 [00:01<13:09, 126371.19tokens/s]
# Shard 1:   0%|          | 221369/100000000 [00:01<12:44, 130567.47tokens/s]
# Shard 1:   0%|          | 235237/100000000 [00:01<12:33, 132462.21tokens/s]
# Shard 1:   0%|          | 248525/100000000 [00:02<13:18, 124943.96tokens/s]
# Shard 1:   0%|          | 261138/100000000 [00:02<13:30, 123104.31tokens/s]
# Shard 1:   0%|          | 274205/100000000 [00:02<13:19, 124799.16tokens/s]
# Shard 1:   0%|          | 288074/100000000 [00:02<12:57, 128217.62tokens/s]
# Shard 1:   0%|          | 300957/100000000 [00:02<12:56, 128368.63tokens/s]
# Shard 1:   0%|          | 314230/100000000 [00:02<12:59, 127818.75tokens/s]
# Shard 1:   0%|          | 327038/100000000 [00:02<13:11, 125925.81tokens/s]
# Shard 1:   0%|          | 340172/100000000 [00:02<13:02, 127332.87tokens/s]
# Shard 1:   0%|          | 353387/100000000 [00:02<12:56, 128268.77tokens/s]
# Shard 1:   0%|          | 366981/100000000 [00:02<12:45, 130221.98tokens/s]
# Shard 1:   0%|          | 380033/100000000 [00:03<13:33, 122436.23tokens/s]
# Shard 1:   0%|          | 393731/100000000 [00:03<13:11, 125789.21tokens/s]
# Shard 1:   0%|          | 407611/100000000 [00:03<12:50, 129180.64tokens/s]

# %%
lines[1000:1500]
# Out:
# ['[BOM]قسم هر روزش بیاید بی جگر[BOM]حاجتش نبود تقاضایی دگر[EOS]',
#  '[BOM]قرعه بر هر که فتادی روز روز[BOM]سوی آن شیر او دویدی همچو یوز[EOS]',
#  '[BOM]چون به خرگوش آمد این ساغر بدور[BOM]بانگ زد خرگوش کاخر چند جور[EOS]',
#  '[BOM]قوم گفتندش که چندین گاه ما[BOM]جان فدا کردیم در عهد و وفا[EOS]',
#  '[BOM]تو مجو بدنامی ما ای عنود[BOM]تا نرنجد شیر رو رو زود زود[EOS]',
#  '[BOM]گفت ای یاران مرا مهلت دهید[BOM]تا بمکرم از بلا بیرون جهید[EOS]',
#  '[BOM]تا امان یابد بمکرم جانتان[BOM]ماند این میراث فرزندانتان[EOS]',
#  '[BOM]هر پیمبر امتان را در جهان[BOM]همچنین تا مخلصی می خواندشان[EOS]',
#  '[BOM]کز فلک راه برون شو دیده بود[BOM]در نظر چون مردمک پیچیده بود[EOS]',
#  '[BOM]مردمش چون مردمک دیدند خرد[BOM]در بزرگی مردمک کس ره نبرد[EOS]',
#  '[BOM]قوم گفتندش که ای خرگوش دار[BOM]خویش را اندازه خرگوش دار[EOS]',
#  '[BOM]هین چه لافست این که از تو بهتران[BOM]در نیاوردند اندر خاطر آن[EOS]',
#  '[BOM]معجبی یا خود قضامان در پیست[BOM]ور نه این دم لایق چون تو کیست[EOS]',
#  '[BOM]گفت ای یاران حقم الهام داد[BOM]مر ضعیفی را قوی رایی فتاد[EOS]',
#  '[BOM]آنچ حق آموخت مر زنبور را[BOM]آن نباشد شیر را و گور را[EOS]',
#  '[BOM]خانه ها سازد پر از حلوای تر[BOM]حق برو آن علم را بگشاد در[EOS]',
#  '[BOM]آنچ حق آموخت کرم پیله را[BOM]هیچ پیلی داند آن گون حیله را[EOS]',
#  '[BOM]آدم خاکی ز حق آموخت علم[BOM]تا به هفتم آسمان افروخت علم[EOS]',
#  '[BOM]نام و ناموس ملک را در شکست[BOM]کوری آنکس که در حق درشکست[EOS]',
#  '[BOM]زاهد ششصد هزاران ساله را[BOM]پوزبندی ساخت آن گوساله را[EOS]',
#  '[BOM]تا نتاند شیر علم دین کشید[BOM]تا نگردد گرد آن قصر مشید[EOS]',
#  '[BOM]علمهای اهل حس شد پوزبند[BOM]تا نگیرد شیر از آن علم بلند[EOS]',
#  '[BOM]قطره دل را یکی گوهر فتاد[BOM]کان به دریاها و گردونها نداد[EOS]',
#  '[BOM]چند صورت آخر ای صورت پرست[BOM]جان بی معنیت از صورت نرست[EOS]',
#  '[BOM]گر بصورت آدمی انسان بدی[BOM]احمد و بوجهل خود یکسان بدی[EOS]',
#  '[BOM]نقش بر دیوار مثل آدمست[BOM]بنگر از صورت چه چیز او کمست[EOS]',
#  '[BOM]جان کمست آن صورت با تاب را[BOM]رو بجو آن گوهر کم یاب را[EOS]',
#  '[BOM]شد سر شیران عالم جمله پست[BOM]چون سگ اصحاب را دادند دست[EOS]',
#  '[BOM]چه زیانستش از آن نقش نفور[BOM]چونک جانش غرق شد در بحر نور[EOS]',
#  '[BOM]وصف و صورت نیست اندر خامه ها[BOM]عالم و عادل بود در نامه ها[EOS]',
#  '[BOM]عالم و عادل همه معنیست بس[BOM]کش نیابی در مکان و پیش و پس[EOS]',
#  '[BOM]می زند بر تن ز سوی لامکان[BOM]می نگنجد در فلک خورشید جان[EOS]',
#  '[BOM]این سخن پایان ندارد هوش دار[BOM]هوش سوی قصه خرگوش دار[EOS]',
#  '[BOM]گوش خر بفروش و دیگر گوش خر[BOM]کین سخن را در نیابد گوش خر[EOS]',
#  '[BOM]رو تو روبه بازی خرگوش بین[BOM]مکر و شیراندازی خرگوش بین[EOS]',
#  '[BOM]خاتم ملک سلیمانست علم[BOM]جمله عالم صورت و جانست علم[EOS]',
#  '[BOM]آدمی را زین هنر بیچاره گشت[BOM]خلق دریاها و خلق کوه و دشت[EOS]',
#  '[BOM]زو پلنگ و شیر ترسان همچو موش[BOM]زو نهنگ و بحر در صفرا و جوش[EOS]',
#  '[BOM]زو پری و دیو ساحلها گرفت[BOM]هر یکی در جای پنهان جا گرفت[EOS]',
#  '[BOM]آدمی را دشمن پنهان بسیست[BOM]آدمی با حذر عاقل کسیست[EOS]',
#  '[BOM]خلق پنهان زشتشان و خوبشان[BOM]می زند در دل بهر دم کوبشان[EOS]',
#  '[BOM]بهر غسل ار در روی در جویبار[BOM]بر تو آسیبی زند در آب خار[EOS]',
#  '[BOM]گر چه پنهان خار در آبست پست[BOM]چونک در تو می خلد دانی که هست[EOS]',
#  '[BOM]خارخار وحیها و وسوسه[BOM]از هزاران کس بود نه یک کسه[EOS]',
#  '[BOM]باش تا حسهای تو مبدل شود[BOM]تا ببینیشان و مشکل حل شود[EOS]',
#  '[BOM]تا سخنهای کیان رد کرده ای[BOM]تا کیان را سرور خود کرده ای[EOS]',
#  '[BOM]بعد از آن گفتند کای خرگوش چست[BOM]در میان آر آنچ در ادراک تست[EOS]',
#  '[BOM]ای که با شیری تو در پیچیده ای[BOM]بازگو رایی که اندیشیده ای[EOS]',
#  '[BOM]مشورت ادراک و هشیاری دهد[BOM]عقلها مر عقل را یاری دهد[EOS]',
#  '[BOM]گفت پیغامبر بکن ای رای زن[BOM]مشورت کالمستشار موتمن[EOS]',
#  '[BOM]گفت هر رازی نشاید باز گفت[BOM]جفت طاق آید گهی گه طاق جفت[EOS]',
#  '[BOM]از صفا گر دم زنی با آینه[BOM]تیره گردد زود با ما آینه[EOS]',
#  '[BOM]در بیان این سه کم جنبان لبت[BOM]از ذهاب و از ذهب وز مذهبت[EOS]',
#  '[BOM]کین سه را خصمست بسیار و عدو[BOM]در کمینت ایستد چون داند او[EOS]',
#  '[BOM]ور بگویی با یکی دو الوداع[BOM]کل سر جاوز الاثنین شاع[EOS]',
#  '[BOM]گر دو سه پرنده را بندی بهم[BOM]بر زمین مانند محبوس از الم[EOS]',
#  '[BOM]مشورت دارند سرپوشیده خوب[BOM]در کنایت با غلط افکن مشوب[EOS]',
#  '[BOM]مشورت کردی پیمبر بسته سر[BOM]گفته ایشانش جواب و بی خبر[EOS]',
#  '[BOM]در مثالی بسته گفتی رای را[BOM]تا ندانند خصم از سر پای را[EOS]',
#  '[BOM]او جواب خویش بگرفتی ازو[BOM]وز سوالش می نبردی غیر بو[EOS]',
#  '[BOM]ساعتی تاخیر کرد اندر شدن[BOM]بعد از آن شد پیش شیر پنجه زن[EOS]',
#  '[BOM]زان سبب کاندر شدن او ماند دیر[BOM]خاک را می کند و می غرید شیر[EOS]',
#  '[BOM]گفت من گفتم که عهد آن خسان[BOM]خام باشد خام و سست و نارسان[EOS]',
#  '[BOM]دمدمه ایشان مرا از خر فکند[BOM]چند بفریبد مرا این دهر چند[EOS]',
#  '[BOM]سخت در ماند امیر سست ریش[BOM]چون نه پس بیند نه پیش از احمقیش[EOS]',
#  '[BOM]راه هموارست زیرش دامها[BOM]قحط معنی درمیان نامها[EOS]',
#  '[BOM]لفظها و نامها چون دامهاست[BOM]لفظ شیرین ریگ آب عمر ماست[EOS]',
#  '[BOM]آن یکی ریگی که جوشد آب ازو[BOM]سخت کم یابست رو آن را بجو[EOS]',
#  '[BOM]منبع حکمت شود حکمت طلب[BOM]فارغ آید او ز تحصیل و سبب[EOS]',
#  '[BOM]لوح حافظ لوح محفوظی شود[BOM]عقل او از روح محظوظی شود[EOS]',
#  '[BOM]چون معلم بود عقلش ز ابتدا[BOM]بعد ازین شد عقل شاگردی ورا[EOS]',
#  '[BOM]عقل چون جبریل گوید احمدا[BOM]گر یکی گامی نهم سوزد مرا[EOS]',
#  '[BOM]تو مرا بگذار زین پس پیش ران[BOM]حد من این بود ای سلطان جان[EOS]',
#  '[BOM]هر که ماند از کاهلی بی شکر و صبر[BOM]او همین داند که گیرد پای جبر[EOS]',
#  '[BOM]هر که جبر آورد خود رنجور کرد[BOM]تا همان رنجوریش در گور کرد[EOS]',
#  '[BOM]گفت پیغمبر که رنجوری بلاغ[BOM]رنج آرد تا بمیرد چون چراغ[EOS]',
#  '[BOM]جبر چه بود بستن اشکسته را[BOM]یا بپیوستن رگی بگسسته را[EOS]',
#  '[BOM]چون درین ره پای خود نشکسته ای[BOM]بر کی می خندی چه پا را بسته ای[EOS]',
#  '[BOM]وانک پایش در ره کوشش شکست[BOM]در رسید او را براق و بر نشست[EOS]',
#  '[BOM]حامل دین بود او محمول شد[BOM]قابل فرمان بد او مقبول شد[EOS]',
#  '[BOM]تاکنون فرمان پذیرفتی ز شاه[BOM]بعد ازین فرمان رساند بر سپاه[EOS]',
#  '[BOM]تاکنون اختر اثر کردی درو[BOM]بعد ازین باشد امیر اختر او[EOS]',
#  '[BOM]گر ترا اشکال آید در نظر[BOM]پس تو شک داری در انشق القمر[EOS]',
#  '[BOM]تازه کن ایمان نی از گفت زبان[BOM]ای هوا را تازه کرده در نهان[EOS]',
#  '[BOM]تا هوا تازه ست ایمان تازه نیست[BOM]کین هوا جز قفل آن دروازه نیست[EOS]',
#  '[BOM]کرده ای تاویل حرف بکر را[BOM]خویش را تاویل کن نه ذکر را[EOS]',
#  '[BOM]بر هوا تاویل قرآن می کنی[BOM]پست و کژ شد از تو معنی سنی[EOS]',
#  '[BOM]آن مگس بر برگ کاه و بول خر[BOM]همچو کشتیبان همی افراشت سر[EOS]',
#  '[BOM]گفت من دریا و کشتی خوانده ام[BOM]مدتی در فکر آن می مانده ام[EOS]',
#  '[BOM]اینک این دریا و این کشتی و من[BOM]مرد کشتیبان و اهل و رای زن[EOS]',
#  '[BOM]بر سر دریا همی راند او عمد[BOM]می نمودش آن قدر بیرون ز حد[EOS]',
#  '[BOM]بود بی حد آن چمین نسبت بدو[BOM]آن نظر که بیند آن را راست کو[EOS]',
#  '[BOM]عالمش چندان بود کش بینشست[BOM]چشم چندین بحر همچندینشست[EOS]',
#  '[BOM]صاحب تاویل باطل چون مگس[BOM]وهم او بول خر و تصویر خس[EOS]',
#  '[BOM]گر مگس تاویل بگذارد برای[BOM]آن مگس را بخت گرداند همای[EOS]',
#  '[BOM]آن مگس نبود کش این عبرت بود[BOM]روح او نه در خور صورت بود[EOS]',
#  '[BOM]همچو آن خرگوش کو بر شیر زد[BOM]روح او کی بود اندر خورد قد[EOS]',
#  '[BOM]شیر می گفت از سر تیزی و خشم[BOM]کز ره گوشم عدو بر بست چشم[EOS]',
#  '[BOM]مکرهای جبریانم بسته کرد[BOM]تیغ چوبینشان تنم را خسته کرد[EOS]',
#  '[BOM]زین سپس من نشنوم آن دمدمه[BOM]بانگ دیوانست و غولان آن همه[EOS]',
#  '[BOM]بر دران ای دل تو ایشان را مه ایست[BOM]پوستشان برکن کشان جز پوست نیست[EOS]',
#  '[BOM]پوست چه بود گفته های رنگ رنگ[BOM]چون زره بر آب کش نبود درنگ[EOS]',
#  '[BOM]این سخن چون پوست و معنی مغز دان[BOM]این سخن چون نقش و معنی همچو جان[EOS]',
#  '[BOM]پوست باشد مغز بد را عیب پوش[BOM]مغز نیکو را ز غیرت غیب پوش[EOS]',
#  '[BOM]چون قلم از باد بد دفتر ز آب[BOM]هرچه بنویسی فنا گردد شتاب[EOS]',
#  '[BOM]نقش آبست ار وفا جویی از آن[BOM]باز گردی دستهای خود گزان[EOS]',
#  '[BOM]باد در مردم هوا و آرزوست[BOM]چون هوا بگذاشتی پیغام هوست[EOS]',
#  '[BOM]خوش بود پیغامهای کردگار[BOM]کو ز سر تا پای باشد پایدار[EOS]',
#  '[BOM]خطبه شاهان بگردد و آن کیا[BOM]جز کیا و خطبه های انبیا[EOS]',
#  '[BOM]زانک بوش پادشاهان از هواست[BOM]بارنامه انبیا از کبریاست[EOS]',
#  '[BOM]از درمها نام شاهان برکنند[BOM]نام احمد تا ابد بر می زنند[EOS]',
#  '[BOM]نام احمد نام جمله انبیاست[BOM]چونک صد آمد نود هم پیش ماست[EOS]',
#  '[BOM]در شدن خرگوش بس تاخیر کرد[BOM]مکر را با خویشتن تقریر کرد[EOS]',
#  '[BOM]در ره آمد بعد تاخیر دراز[BOM]تا به گوش شیر گوید یک دو راز[EOS]',
#  '[BOM]تا چه عالمهاست در سودای عقل[BOM]تا چه با پهناست این دریای عقل[EOS]',
#  '[BOM]صورت ما اندرین بحر عذاب[BOM]می دود چون کاسه ها بر روی آب[EOS]',
#  '[BOM]تا نشد پر بر سر دریا چو طشت[BOM]چونک پر شد طشت در وی غرق گشت[EOS]',
#  '[BOM]عقل پنهانست و ظاهر عالمی[BOM]صورت ما موج یا از وی نمی[EOS]',
#  '[BOM]هر چه صورت می وسیلت سازدش[BOM]زان وسیلت بحر دور اندازدش[EOS]',
#  '[BOM]تا نبیند دل دهنده راز را[BOM]تا نبیند تیر دورانداز را[EOS]',
#  '[BOM]اسپ خود را یاوه داند وز ستیز[BOM]می دواند اسپ خود در راه تیز[EOS]',
#  '[BOM]اسپ خود را یاوه داند آن جواد[BOM]و اسپ خود او را کشان کرده چو باد[EOS]',
#  '[BOM]در فغان و جست و جو آن خیره سر[BOM]هر طرف پرسان و جویان در بدر[EOS]',
#  '[BOM]کانک دزدید اسپ ما را کو و کیست[BOM]این که زیر ران تست ای خواجه چیست[EOS]',
#  '[BOM]آری این اسپست لیک این اسپ کو[BOM]با خود آی ای شهسوار اسپ جو[EOS]',
#  '[BOM]جان ز پیدایی و نزدیکیست گم[BOM]چون شکم پر آب و لب خشکی چو خم[EOS]',
#  '[BOM]کی ببینی سرخ و سبز و فور را[BOM]تا نبینی پیش ازین سه نور را[EOS]',
#  '[BOM]لیک چون در رنگ گم شد هوش تو[BOM]شد ز نور آن رنگها روپوش تو[EOS]',
#  '[BOM]چونک شب آن رنگها مستور بود[BOM]پس بدیدی دید رنگ از نور بود[EOS]',
#  '[BOM]نیست دید رنگ بی نور برون[BOM]همچنین رنگ خیال اندرون[EOS]',
#  '[BOM]این برون از آفتاب و از سها[BOM]واندرون از عکس انوار علا[EOS]',
#  '[BOM]نور نور چشم خود نور دلست[BOM]نور چشم از نور دلها حاصلست[EOS]',
#  '[BOM]باز نور نور دل نور خداست[BOM]کو ز نور عقل و حس پاک و جداست[EOS]',
#  '[BOM]شب نبد نور و ندیدی رنگها[BOM]پس به ضد نور پیدا شد ترا[EOS]',
#  '[BOM]دیدن نورست آنگه دید رنگ[BOM]وین به ضد نور دانی بی درنگ[EOS]',
#  '[BOM]رنج و غم را حق پی آن آفرید[BOM]تا بدین ضد خوش دلی آید پدید[EOS]',
#  '[BOM]پس نهانیها بضد پیدا شود[BOM]چونک حق را نیست ضد پنهان بود[EOS]',
#  '[BOM]که نظر پر نور بود آنگه برنگ[BOM]ضد به ضد پیدا بود چون روم و زنگ[EOS]',
#  '[BOM]پس به ضد نور دانستی تو نور[BOM]ضد ضد را می نماید در صدور[EOS]',
#  '[BOM]نور حق را نیست ضدی در وجود[BOM]تا به ضد او را توان پیدا نمود[EOS]',
#  '[BOM]لاجرم ابصار ما لا تدرکه[BOM]و هو یدرک بین تو از موسی و که[EOS]',
#  '[BOM]صورت از معنی چو شیر از بیشه دان[BOM]یا چو آواز و سخن ز اندیشه دان[EOS]',
#  '[BOM]این سخن و آواز از اندیشه خاست[BOM]تو ندانی بحر اندیشه کجاست[EOS]',
#  '[BOM]لیک چون موج سخن دیدی لطیف[BOM]بحر آن دانی که باشد هم شریف[EOS]',
#  '[BOM]چون ز دانش موج اندیشه بتاخت[BOM]از سخن و آواز او صورت بساخت[EOS]',
#  '[BOM]از سخن صورت بزاد و باز مرد[BOM]موج خود را باز اندر بحر برد[EOS]',
#  '[BOM]صورت از بی صورتی آمد برون[BOM]باز شد که انا الیه راجعون[EOS]',
#  '[BOM]پس ترا هر لحظه مرگ و رجعتیست[BOM]مصطفی فرمود دنیا ساعتیست[EOS]',
#  '[BOM]فکر ما تیریست از هو در هوا[BOM]در هوا کی پاید آید تا خدا[EOS]',
#  '[BOM]هر نفس نو می شود دنیا و ما[BOM]بی خبر از نو شدن اندر بقا[EOS]',
#  '[BOM]عمر همچون جوی نو نو می رسد[BOM]مستمری می نماید در جسد[EOS]',
#  '[BOM]آن ز تیزی مستمر شکل آمده ست[BOM]چون شرر کش تیز جنبانی بدست[EOS]',
#  '[BOM]شاخ آتش را بجنبانی بساز[BOM]در نظر آتش نماید بس دراز[EOS]',
#  '[BOM]این درازی مدت از تیزی صنع[BOM]می نماید سرعت انگیزی صنع[EOS]',
#  '[BOM]طالب این سر اگر علامه ایست[BOM]نک حسام الدین که سامی نامه ایست[EOS]',
#  '[BOM]شیر اندر آتش و در خشم و شور[BOM]دید کان خرگوش می آید ز دور[EOS]',
#  '[BOM]می دود بی دهشت و گستاخ او[BOM]خشمگین و تند و تیز و ترش رو[EOS]',
#  '[BOM]کز شکسته آمدن تهمت بود[BOM]وز دلیری دفع هر ریبت بود[EOS]',
#  '[BOM]چون رسید او پیشتر نزدیک صف[BOM]بانگ بر زد شیرهای ای ناخلف[EOS]',
#  '[BOM]من که پیلان را ز هم بدریده ام[BOM]من که گوش شیر نر مالیده ام[EOS]',
#  '[BOM]نیم خرگوشی که باشد که چنین[BOM]امر ما را افکند او بر زمین[EOS]',
#  '[BOM]ترک خواب غفلت خرگوش کن[BOM]غره این شیر ای خرگوش کن[EOS]',
#  '[BOM]گفت خرگوش الامان عذریم هست[BOM]گر دهد عفو خداوندیت دست[EOS]',
#  '[BOM]گفت چه عذر ای قصور ابلهان[BOM]این زمان آیند در پیش شهان[EOS]',
#  '[BOM]مرغ بی وقتی سرت باید برید[BOM]عذر احمق را نمی شاید شنید[EOS]',
#  '[BOM]عذر احمق بتر از جرمش بود[BOM]عذر نادان زهر هر دانش بود[EOS]',
#  '[BOM]عذرت ای خرگوش از دانش تهی[BOM]من نه خرگوشم که در گوشم نهی[EOS]',
#  '[BOM]گفت ای شه ناکسی را کس شمار[BOM]عذر استم دیده ای را گوش دار[EOS]',
#  '[BOM]خاص از بهر زکات جاه خود[BOM]گمرهی را تو مران از راه خود[EOS]',
#  '[BOM]بحر کو آبی به هر جو می دهد[BOM]هر خسی را بر سر و رو می نهد[EOS]',
#  '[BOM]کم نخواهد گشت دریا زین کرم[BOM]از کرم دریا نگردد بیش و کم[EOS]',
#  '[BOM]گفت دارم من کرم بر جای او[BOM]جامه هر کس برم بالای او[EOS]',
#  '[BOM]گفت بشنو گر نباشم جای لطف[BOM]سر نهادم پیش اژدرهای عنف[EOS]',
#  '[BOM]من بوقت چاشت در راه آمدم[BOM]با رفیق خود سوی شاه آمدم[EOS]',
#  '[BOM]با من از بهر تو خرگوشی دگر[BOM]جفت و همره کرده بودند آن نفر[EOS]',
#  '[BOM]شیری اندر راه قصد بنده کرد[BOM]قصد هر دو همره آینده کرد[EOS]',
#  '[BOM]گفتمش ما بنده شاهنشهیم[BOM]خواجه تاشان که آن درگهیم[EOS]',
#  '[BOM]گفت شاهنشه کی باشد شرم دار[BOM]پیش من تو یاد هر ناکس میار[EOS]',
#  '[BOM]هم ترا و هم شهت را بر درم[BOM]گر تو با یارت بگردید از درم[EOS]',
#  '[BOM]گفتمش بگذار تا بار دگر[BOM]روی شه بینم برم از تو خبر[EOS]',
#  '[BOM]گفت همره را گرو نه پیش من[BOM]ور نه قربانی تو اندر کیش من[EOS]',
#  '[BOM]لابه کردیمش بسی سودی نکرد[BOM]یار من بستد مرا بگذاشت فرد[EOS]',
#  '[BOM]یارم از زفتی دو چندان بد که من[BOM]هم بلطف و هم بخوبی هم بتن[EOS]',
#  '[BOM]بعد ازین زان شیر این ره بسته شد[BOM]حال ما این بود و با تو گفته شد[EOS]',
#  '[BOM]از وظیفه بعد ازین اومید بر[BOM]حق همی گویم ترا والحق مر[EOS]',
#  '[BOM]گر وظیفه بایدت ره پاک کن[BOM]هین بیا و دفع آن بی باک کن[EOS]',
#  '[BOM]گفت بسم الله بیا تا او کجاست[BOM]پیش در شو گر همی گویی تو راست[EOS]',
#  '[BOM]تا سزای او و صد چون او دهم[BOM]ور دروغست این سزای تو دهم[EOS]',
#  '[BOM]اندر آمد چون قلاووزی به پیش[BOM]تا برد او را به سوی دام خویش[EOS]',
#  '[BOM]سوی چاهی کو نشانش کرده بود[BOM]چاه مغ را دام جانش کرده بود[EOS]',
#  '[BOM]می شدند این هر دو تا نزدیک چاه[BOM]اینت خرگوشی چو آبی زیر کاه[EOS]',
#  '[BOM]آب کاهی را به هامون می برد[BOM]آب کوهی را عجب چون می برد[EOS]',
#  '[BOM]دام مکر او کمند شیر بود[BOM]طرفه خرگوشی که شیری می ربود[EOS]',
#  '[BOM]موسیی فرعون را با رود نیل[BOM]می کشد با لشکر و جمع ثقیل[EOS]',
#  '[BOM]پشه ای نمرود را با نیم پر[BOM]می شکافد بی محابا درز سر[EOS]',
#  '[BOM]حال آن کو قول دشمن را شنود[BOM]بین جزای آنک شد یار حسود[EOS]',
#  '[BOM]حال فرعونی که هامان را شنود[BOM]حال نمرودی که شیطان را شنود[EOS]',
#  '[BOM]دشمن ار چه دوستانه گویدت[BOM]دام دان گر چه ز دانه گویدت[EOS]',
#  '[BOM]گر ترا قندی دهد آن زهر دان[BOM]گر بتن لطفی کند آن قهر دان[EOS]',
#  '[BOM]چون قضا آید نبینی غیر پوست[BOM]دشمنان را باز نشناسی ز دوست[EOS]',
#  '[BOM]چون چنین شد ابتهال آغاز کن[BOM]ناله و تسبیح و روزه ساز کن[EOS]',
#  '[BOM]ناله می کن کای تو علام الغیوب[BOM]زیر سنگ مکر بد ما را مکوب[EOS]',
#  '[BOM]گر سگی کردیم ای شیرآفرین[BOM]شیر را مگمار بر ما زین کمین[EOS]',
#  '[BOM]آب خوش را صورت آتش مده[BOM]اندر آتش صورت آبی منه[EOS]',
#  '[BOM]از شراب قهر چون مستی دهی[BOM]نیستها را صورت هستی دهی[EOS]',
#  '[BOM]چیست مستی بند چشم از دید چشم[BOM]تا نماند سنگ گوهر پشم یشم[EOS]',
#  '[BOM]چیست مستی حسها مبدل شدن[BOM]چوب گز اندر نظر صندل شدن[EOS]',
#  '[BOM]چون سلیمان را سراپرده زدند[BOM]جمله مرغانش به خدمت آمدند[EOS]',
#  '[BOM]هم زبان و محرم خود یافتند[BOM]پیش او یک یک بجان بشتافتند[EOS]',
#  '[BOM]جمله مرغان ترک کرده چیک چیک[BOM]با سلیمان گشته افصح من اخیک[EOS]',
#  '[BOM]همزبانی خویشی و پیوندی است[BOM]مرد با نامحرمان چون بندی است[EOS]',
#  '[BOM]ای بسا هندو و ترک همزبان[BOM]ای بسا دو ترک چون بیگانگان[EOS]',
#  '[BOM]پس زبان محرمی خود دیگرست[BOM]همدلی از همزبانی بهترست[EOS]',
#  '[BOM]غیرنطق و غیر ایما و سجل[BOM]صد هزاران ترجمان خیزد ز دل[EOS]',
#  '[BOM]جمله مرغان هر یکی اسرار خود[BOM]از هنر وز دانش و از کار خود[EOS]',
#  '[BOM]با سلیمان یک بیک وا می نمود[BOM]از برای عرضه خود را می ستود[EOS]',
#  '[BOM]از تکبر نه و از هستی خویش[BOM]بهر آن تا ره دهد او را به پیش[EOS]',
#  '[BOM]چون بباید برده را از خواجه ای[BOM]عرضه دارد از هنر دیباجه ای[EOS]',
#  '[BOM]چونک دارد از خریداریش ننگ[BOM]خود کند بیمار و کر و شل و لنگ[EOS]',
#  '[BOM]نوبت هدهد رسید و پیشه اش[BOM]و آن بیان صنعت و اندیشه اش[EOS]',
#  '[BOM]گفت ای شه یک هنر کان کهترست[BOM]باز گویم گفت کوته بهترست[EOS]',
#  '[BOM]گفت بر گو تا کدامست آن هنر[BOM]گفت من آنگه که باشم اوج بر[EOS]',
#  '[BOM]بنگرم از اوج با چشم یقین[BOM]من ببینم آب در قعر زمین[EOS]',
#  '[BOM]تا کجایست و چه عمقستش چه رنگ[BOM]از چه می جوشد ز خاکی یا ز سنگ[EOS]',
#  '[BOM]ای سلیمان بهر لشگرگاه را[BOM]در سفر می دار این آگاه را[EOS]',
#  '[BOM]پس سلیمان گفت ای نیکو رفیق[BOM]در بیابانهای بی آب عمیق[EOS]',
#  '[BOM]زاغ چون بشنود آمد از حسد[BOM]با سلیمان گفت کو کژ گفت و بد[EOS]',
#  '[BOM]از ادب نبود به پیش شه مقال[BOM]خاصه خودلاف دروغین و محال[EOS]',
#  '[BOM]گر مر او را این نظر بودی مدام[BOM]چون ندیدی زیر مشتی خاک دام[EOS]',
#  '[BOM]چون گرفتار آمدی در دام او[BOM]چون قفس اندر شدی ناکام او[EOS]',
#  '[BOM]پس سلیمان گفت ای هدهد رواست[BOM]کز تو در اول قدح این درد خاست[EOS]',
#  '[BOM]چون نمایی مستی ای خورده تو دوغ[BOM]پیش من لافی زنی آنگه دروغ[EOS]',
#  '[BOM]گفت ای شه بر من عور گدای[BOM]قول دشمن مشنو از بهر خدای[EOS]',
#  '[BOM]گر به بطلانست دعوی کردنم[BOM]من نهادم سر ببر این گردنم[EOS]',
#  '[BOM]زاغ کو حکم قضا را منکرست[BOM]گر هزاران عقل دارد کافرست[EOS]',
#  '[BOM]در تو تا کافی بود از کافران[BOM]جای گند و شهوتی چون کاف ران[EOS]',
#  '[BOM]من ببینم دام را اندر هوا[BOM]گر نپوشد چشم عقلم را قضا[EOS]',
#  '[BOM]چون قضا آید شود دانش بخواب[BOM]مه سیه گردد بگیرد آفتاب[EOS]',
#  '[BOM]از قضا این تعبیه کی نادرست[BOM]از قضا دان کو قضا را منکرست[EOS]',
#  '[BOM]بوالبشر کو علم الاسما بگست[BOM]صد هزاران علمش اندر هر رگست[EOS]',
#  '[BOM]اسم هر چیزی چنان کان چیز هست[BOM]تا به پایان جان او را داد دست[EOS]',
#  '[BOM]هر لقب کو داد آن مبدل نشد[BOM]آنک چستش خواند او کاهل نشد[EOS]',
#  '[BOM]هر که اول مومنست اول بدید[BOM]هر که آخر کافر او را شد پدید[EOS]',
#  '[BOM]اسم هر چیزی تو از دانا شنو[BOM]سر رمز علم الاسما شنو[EOS]',
#  '[BOM]اسم هر چیزی بر ما ظاهرش[BOM]اسم هر چیزی بر خالق سرش[EOS]',
#  '[BOM]نزد موسی نام چوبش بد عصا[BOM]نزد خالق بود نامش اژدها[EOS]',
#  '[BOM]بد عمر را نام اینجا بت پرست[BOM]لیک مومن بود نامش در الست[EOS]',
#  '[BOM]آنک بد نزدیک ما نامش منی[BOM]پیش حق این نقش بد که با منی[EOS]',
#  '[BOM]صورتی بود این منی اندر عدم[BOM]پیش حق موجود نه بیش و نه کم[EOS]',
#  '[BOM]حاصل آن آمد حقیقت نام ما[BOM]پیش حضرت کان بود انجام ما[EOS]',
#  '[BOM]مرد را بر عاقبت نامی نهد[BOM]نی بر آن کو عاریت نامی نهد[EOS]',
#  '[BOM]چشم آدم چون به نور پاک دید[BOM]جان و سر نامها گشتش پدید[EOS]',
#  '[BOM]چون ملک انوار حق در وی بیافت[BOM]در سجود افتاد و در خدمت شتافت[EOS]',
#  '[BOM]مدح این آدم که نامش می برم[BOM]قاصرم گر تا قیامت بشمرم[EOS]',
#  '[BOM]این همه دانست و چون آمد قضا[BOM]دانش یک نهی شد بر وی خطا[EOS]',
#  '[BOM]کای عجب نهی از پی تحریم بود[BOM]یا به تاویلی بد و توهیم بود[EOS]',
#  '[BOM]در دلش تاویل چون ترجیح یافت[BOM]طبع در حیرت سوی گندم شتافت[EOS]',
#  '[BOM]باغبان را خار چون در پای رفت[BOM]دزد فرصت یافت کالا برد تفت[EOS]',
#  '[BOM]چون ز حیرت رست باز آمد به راه[BOM]دید برده دزد رخت از کارگاه[EOS]',
#  '[BOM]ربنا انا ظلمنا گفت و آه[BOM]یعنی آمد ظلمت و گم گشت راه[EOS]',
#  '[BOM]پس قضا ابری بود خورشیدپوش[BOM]شیر و اژدرها شود زو همچو موش[EOS]',
#  '[BOM]من اگر دامی نبینم گاه حکم[BOM]من نه تنها جاهلم در راه حکم[EOS]',
#  '[BOM]ای خنک آن کو نکوکاری گرفت[BOM]زور را بگذاشت او زاری گرفت[EOS]',
#  '[BOM]گر قضا پوشد سیه همچون شبت[BOM]هم قضا دستت بگیرد عاقبت[EOS]',
#  '[BOM]گر قضا صد بار قصد جان کند[BOM]هم قضا جانت دهد درمان کند[EOS]',
#  '[BOM]این قضا صد بار اگر راهت زند[BOM]بر فراز چرخ خرگاهت زند[EOS]',
#  '[BOM]از کرم دان این که می ترساندت[BOM]تا به ملک ایمنی بنشاندت[EOS]',
#  '[BOM]این سخن پایان ندارد گشت دیر[BOM]گوش کن تو قصه خرگوش و شیر[EOS]',
#  '[BOM]چونک نزد چاه آمد شیر دید[BOM]کز ره آن خرگوش ماند و پا کشید[EOS]',
#  '[BOM]گفت پا واپس کشیدی تو چرا[BOM]پای را واپس مکش پیش اندر آ[EOS]',
#  '[BOM]گفت کو پایم که دست و پای رفت[BOM]جان من لرزید و دل از جای رفت[EOS]',
#  '[BOM]رنگ رویم را نمی بینی چو زر[BOM]ز اندرون خود می دهد رنگم خبر[EOS]',
#  '[BOM]حق چو سیما را معرف خوانده ست[BOM]چشم عارف سوی سیما مانده ست[EOS]',
#  '[BOM]رنگ و بو غماز آمد چون جرس[BOM]از فرس آگه کند بانگ فرس[EOS]',
#  '[BOM]بانگ هر چیزی رساند زو خبر[BOM]تا بدانی بانگ خر از بانگ در[EOS]',
#  '[BOM]گفت پیغامبر به تمییز کسان[BOM]مر مخفی لدی طی اللسان[EOS]',
#  '[BOM]رنگ رو از حال دل دارد نشان[BOM]رحمتم کن مهر من در دل نشان[EOS]',
#  '[BOM]رنگ روی سرخ دارد بانگ شکر[BOM]بانگ روی زرد دارد صبر و نکر[EOS]',
#  '[BOM]در من آمد آنک دست و پا برد[BOM]رنگ رو و قوت و سیما برد[EOS]',
#  '[BOM]آنک در هر چه در آید بشکند[BOM]هر درخت از بیخ و بن او بر کند[EOS]',
#  '[BOM]در من آمد آنک از وی گشت مات[BOM]آدمی و جانور جامد نبات[EOS]',
#  '[BOM]این خود اجزا اند کلیات ازو[BOM]زرد کرده رنگ و فاسد کرده بو[EOS]',
#  '[BOM]تا جهان گه صابرست و گه شکور[BOM]بوستان گه حله پوشد گاه عور[EOS]',
#  '[BOM]آفتابی کو بر آید نارگون[BOM]ساعتی دیگر شود او سرنگون[EOS]',
#  '[BOM]اختران تافته بر چار طاق[BOM]لحظه لحظه مبتلای احتراق[EOS]',
#  '[BOM]ماه کو افزود ز اختر در جمال[BOM]شد ز رنج دق او همچون خیال[EOS]',
#  '[BOM]این زمین با سکون با ادب[BOM]اندر آرد زلزله ش در لرز تب[EOS]',
#  '[BOM]ای بسا که زین بلای مر دریگ[BOM]گشته است اندر جهان او خرد و ریگ[EOS]',
#  '[BOM]این هوا با روح آمد مقترن[BOM]چون قضا آید وبا گشت و عفن[EOS]',
#  '[BOM]آب خوش کو روح را همشیره شد[BOM]در غدیری زرد و تلخ و تیره شد[EOS]',
#  '[BOM]آتشی کو باد دارد در بروت[BOM]هم یکی بادی برو خواند یموت[EOS]',
#  '[BOM]حال دریا ز اضطراب و جوش او[BOM]فهم کن تبدیلهای هوش او[EOS]',
#  '[BOM]چرخ سرگردان که اندر جست و جوست[BOM]حال او چون حال فرزندان اوست[EOS]',
#  '[BOM]گه حضیض و گه میانه گاه اوج[BOM]اندرو از سعد و نحسی فوج فوج[EOS]',
#  '[BOM]از خود ای جزوی ز کلها مختلط[BOM]فهم می کن حالت هر منبسط[EOS]',
#  '[BOM]چونک کلیات را رنجست و درد[BOM]جزو ایشان چون نباشد روی زرد[EOS]',
#  '[BOM]خاصه جزوی کو ز اضدادست جمع[BOM]ز آب و خاک و آتش و بادست جمع[EOS]',
#  '[BOM]این عجب نبود که میش از گرگ جست[BOM]این عجب کین میش دل در گرگ بست[EOS]',
#  '[BOM]زندگانی آشتی ضدهاست[BOM]مرگ آنک اندر میانش جنگ خاست[EOS]',
#  '[BOM]لطف حق این شیر را و گور را[BOM]الف دادست این دو ضد دور را[EOS]',
#  '[BOM]چون جهان رنجور و زندانی بود[BOM]چه عجب رنجور اگر فانی بود[EOS]',
#  '[BOM]خواند بر شیر او ازین رو پندها[BOM]گفت من پس مانده ام زین بندها[EOS]',
#  '[BOM]شیر گفتش تو ز اسباب مرض[BOM]این سبب گو خاص کاینستم غرض[EOS]',
#  '[BOM]گفت آن شیر اندرین چه ساکنست[BOM]اندرین قلعه ز آفات آمنست[EOS]',
#  '[BOM]قعر چه بگزید هر که عاقلست[BOM]زانک در خلوت صفاهای دلست[EOS]',
#  '[BOM]ظلمت چه به که ظلمتهای خلق[BOM]سر نبرد آنکس که گیرد پای خلق[EOS]',
#  '[BOM]گفت پیش آ زخمم او را قاهرست[BOM]تو ببین کان شیر در چه حاضرست[EOS]',
#  '[BOM]گفت من سوزیده ام زان آتشی[BOM]تو مگر اندر بر خویشم کشی[EOS]',
#  '[BOM]تا به پشت تو من ای کان کرم[BOM]چشم بگشایم بچه در بنگرم[EOS]',
#  '[BOM]چونک شیر اندر بر خویشش کشید[BOM]در پناه شیر تا چه می دوید[EOS]',
#  '[BOM]چونک در چه بنگریدند اندر آب[BOM]اندر آب از شیر و او در تافت تاب[EOS]',
#  '[BOM]شیر عکس خویش دید از آب تفت[BOM]شکل شیری در برش خرگوش زفت[EOS]',
#  '[BOM]چونک خصم خویش را در آب دید[BOM]مر ورا بگذاشت و اندر چه جهید[EOS]',
#  '[BOM]در فتاد اندر چهی کو کنده بود[BOM]زانک ظلمش در سرش آینده بود[EOS]',
#  '[BOM]چاه مظلم گشت ظلم ظالمان[BOM]این چنین گفتند جمله عالمان[EOS]',
#  '[BOM]هر که ظالم تر چهش با هول تر[BOM]عدل فرمودست بتر را بتر[EOS]',
#  '[BOM]ای که تو از جاه ظلمی می کنی[BOM]دانک بهر خویش چاهی می کنی[EOS]',
#  '[BOM]گرد خود چون کرم پیله بر متن[BOM]بهر خود چه می کنی اندازه کن[EOS]',
#  '[BOM]مر ضعیفان را تو بی خصمی مدان[BOM]از نبی ذا جا نصر الله خوان[EOS]',
#  '[BOM]گر تو پیلی خصم تو از تو رمید[BOM]نک جزا طیرا ابابیلت رسید[EOS]',
#  '[BOM]گر ضعیفی در زمین خواهد امان[BOM]غلغل افتد در سپاه آسمان[EOS]',
#  '[BOM]گر بدندانش گزی پر خون کنی[BOM]درد دندانت بگیرد چون کنی[EOS]',
#  '[BOM]شیر خود را دید در چه وز غلو[BOM]خویش را نشناخت آن دم از عدو[EOS]',
#  '[BOM]عکس خود را او عدو خویش دید[BOM]لاجرم بر خویش شمشیری کشید[EOS]',
#  '[BOM]ای بسا ظلمی که بینی در کسان[BOM]خوی تو باشد دریشان ای فلان[EOS]',
#  '[BOM]اندریشان تافته هستی تو[BOM]از نفاق و ظلم و بد مستی تو[EOS]',
#  '[BOM]آن توی و آن زخم بر خود می زنی[BOM]بر خود آن دم تار لعنت می تنی[EOS]',
#  '[BOM]در خود آن بد را نمی بینی عیان[BOM]ورنه دشمن بودیی خود را بجان[EOS]',
#  '[BOM]حمله بر خود می کنی ای ساده مرد[BOM]همچو آن شیری که بر خود حمله کرد[EOS]',
#  '[BOM]چون به قعر خوی خود اندر رسی[BOM]پس بدانی کز تو بود آن ناکسی[EOS]',
#  '[BOM]شیر را در قعر پیدا شد که بود[BOM]نقش او آنکش دگر کس می نمود[EOS]',
#  '[BOM]هر که دندان ضعیفی می کند[BOM]کار آن شیر غلط بین می کند[EOS]',
#  '[BOM]می ببیند خال بد بر روی عم[BOM]عکس خال تست آن از عم مرم[EOS]',
#  '[BOM]مومنان آیینه همدیگرند[BOM]این خبر می از پیمبر آورند[EOS]',
#  '[BOM]پیش چشمت داشتی شیشه کبود[BOM]زان سبب عالم کبودت می نمود[EOS]',
#  '[BOM]گر نه کوری این کبودی دان ز خویش[BOM]خویش را بد گو مگو کس را تو بیش[EOS]',
#  '[BOM]مومن ار ینظر بنور الله نبود[BOM]غیب مومن را برهنه چون نمود[EOS]',
#  '[BOM]چون که تو ینظر بنار الله بدی[BOM]در بدی از نیکوی غافل شدی[EOS]',
#  '[BOM]اندک اندک آب بر آتش بزن[BOM]تا شود نار تو نور ای بوالحزن[EOS]',
#  '[BOM]تو بزن یا ربنا آب طهور[BOM]تا شود این نار عالم جمله نور[EOS]',
#  '[BOM]آب دریا جمله در فرمان تست[BOM]آب و آتش ای خداوند آن تست[EOS]',
#  '[BOM]گر تو خواهی آتش آب خوش شود[BOM]ور نخواهی آب هم آتش شود[EOS]',
#  '[BOM]این طلب در ما هم از ایجاد تست[BOM]رستن از بیداد یا رب داد تست[EOS]',
#  '[BOM]بی طلب تو این طلب مان داده ای[BOM]گنج احسان بر همه بگشاده ای[EOS]',
#  '[BOM]چونک خرگوش از رهایی شاد گشت[BOM]سوی نخچیران دوان شد تا به دشت[EOS]',
#  '[BOM]شیر را چون دید در چه کشته زار[BOM]چرخ می زد شادمان تا مرغزار[EOS]',
#  '[BOM]دست می زد چون رهید از دست مرگ[BOM]سبز و رقصان در هوا چون شاخ و برگ[EOS]',
#  '[BOM]شاخ و برگ از حبس خاک آزاد شد[BOM]سر برآورد و حریف باد شد[EOS]',
#  '[BOM]برگها چون شاخ را بکشافتند[BOM]تا به بالای درخت اشتافتند[EOS]',
#  '[BOM]با زبان شطاه شکر خدا[BOM]می سراید هر بر و برگی جدا[EOS]',
#  '[BOM]که بپرورد اصل ما را ذوالعطا[BOM]تا درخت استغلظ آمد و استوی[EOS]',
#  '[BOM]جانهای بسته اندر آب و گل[BOM]چون رهند از آب و گلها شاددل[EOS]',
#  '[BOM]در هوای عشق حق رقصان شوند[BOM]همچو قرص بدر بی نقصان شوند[EOS]',
#  '[BOM]چشمان در رقص و جانها خود مپرس[BOM]وانک گرد جان از آنها خود مپرس[EOS]',
#  '[BOM]شیر را خرگوش در زندان نشاند[BOM]ننگ شیری کو ز خرگوشی بماند[EOS]',
#  '[BOM]درچنان ننگی و آنگه این عجب[BOM]فخر دین خواهد که گویندش لقب[EOS]',
#  '[BOM]ای تو شیری در تک این چاه فرد[BOM]نقش چون خرگوش خونت ریخت و خورد[EOS]',
#  '[BOM]نفس خرگوشت به صحرا در چرا[BOM]تو بقعر این چه چون و چرا[EOS]',
#  '[BOM]سوی نخچیران دوید آن شیرگیر[BOM]کابشروا یا قوم اذ جا البشیر[EOS]',
#  '[BOM]مژده مژده ای گروه عیش ساز[BOM]کان سگ دوزخ به دوزخ رفت باز[EOS]',
#  '[BOM]مژده مژده کان عدو جانها[BOM]کند قهر خالقش دندانها[EOS]',
#  '[BOM]آنک از پنجه بسی سرها بکوفت[BOM]همچو خس جاروب مرگش هم بروفت[EOS]',
#  '[BOM]جمع گشتند آن زمان جمله وحوش[BOM]شاد و خندان از طرب در ذوق و جوش[EOS]',
#  '[BOM]حلقه کردند او چو شمعی در میان[BOM]سجده آوردند و گفتندش که هان[EOS]',
#  '[BOM]تو فرشته آسمانی یا پری[BOM]نی تو عزراییل شیران نری[EOS]',
#  '[BOM]هرچه هستی جان ما قربان تست[BOM]دست بردی دست و بازویت درست[EOS]',
#  '[BOM]راند حق این آب را در جوی تو[BOM]آفرین بر دست و بر بازوی تو[EOS]',
#  '[BOM]باز گو تا چون سگالیدی به مکر[BOM]آن عوان را چون بمالیدی به مکر[EOS]',
#  '[BOM]بازگو تا قصه درمانها شود[BOM]بازگو تا مرهم جانها شود[EOS]',
#  '[BOM]بازگو کز ظلم آن استم نما[BOM]صد هزاران زخم دارد جان ما[EOS]',
#  '[BOM]گفت تایید خدا بد ای مهان[BOM]ورنه خرگوشی کی باشد در جهان[EOS]',
#  '[BOM]قوتم بخشید و دل را نور داد[BOM]نور دل مر دست و پا را زور داد[EOS]',
#  '[BOM]از بر حق می رسد تفضیلها[BOM]باز هم از حق رسد تبدیلها[EOS]',
#  '[BOM]حق بدور نوبت این تایید را[BOM]می نماید اهل ظن و دید را[EOS]',
#  '[BOM]هین بملک نوبتی شادی مکن[BOM]ای تو بسته نوبت آزادی مکن[EOS]',
#  '[BOM]آنک ملکش برتر از نوبت تنند[BOM]برتر از هفت انجمش نوبت زنند[EOS]',
#  '[BOM]برتر از نوبت ملوک باقیند[BOM]دور دایم روحها با ساقیند[EOS]',
#  '[BOM]ترک این شرب ار بگویی یک دو روز[BOM]در کنی اندر شراب خلد پوز[EOS]',
#  '[BOM]ای شهان کشتیم ما خصم برون[BOM]ماند خصمی زو بتر در اندرون[EOS]',
#  '[BOM]کشتن این کار عقل و هوش نیست[BOM]شیر باطن سخره خرگوش نیست[EOS]',
#  '[BOM]دوزخست این نفس و دوزخ اژدهاست[BOM]کو به دریاها نگردد کم و کاست[EOS]',
#  '[BOM]هفت دریا را در آشامد هنوز[BOM]کم نگردد سوزش آن خلق سوز[EOS]',
#  '[BOM]سنگها و کافران سنگ دل[BOM]اندر آیند اندرو زار و خجل[EOS]',
#  '[BOM]هم نگردد ساکن از چندین غذا[BOM]تا ز حق آید مرورا این ندا[EOS]',
#  '[BOM]سیر گشتی سیر گوید نه هنوز[BOM]اینت آتش اینت تابش اینت سوز[EOS]',
#  '[BOM]عالمی را لقمه کرد و در کشید[BOM]معده اش نعره زنان هل من مزید[EOS]',
#  '[BOM]حق قدم بر وی نهد از لامکان[BOM]آنگه او ساکن شود از کن فکان[EOS]',
#  '[BOM]چونک جزو دوزخست این نفس ما[BOM]طبع کل دارد همیشه جزوها[EOS]',
#  '[BOM]این قدم حق را بود کو را کشد[BOM]غیر حق خود کی کمان او کشد[EOS]',
#  '[BOM]در کمان ننهند الا تیر راست[BOM]این کمان را بازگون کژ تیرهاست[EOS]',
#  '[BOM]راست شو چون تیر و واره از کمان[BOM]کز کمان هر راست بجهد بی گمان[EOS]',
#  '[BOM]چونک وا گشتم ز پیگار برون[BOM]روی آوردم به پیگار درون[EOS]',
#  '[BOM]قد رجعنا من جهاد الاصغریم[BOM]با نبی اندر جهاد اکبریم[EOS]',
#  '[BOM]قوت از حق خواهم و توفیق و لاف[BOM]تا به سوزن بر کنم این کوه قاف[EOS]',
#  '[BOM]سهل شیری دان که صفها بشکند[BOM]شیر آنست آن که خود را بشکند[EOS]',
#  '[BOM]تا عمر آمد ز قیصر یک رسول[BOM]در مدینه از بیابان نغول[EOS]',
#  '[BOM]گفت کو قصر خلیفه ای حشم[BOM]تا من اسپ و رخت را آنجا کشم[EOS]',
#  '[BOM]قوم گفتندش که او را قصر نیست[BOM]مر عمر را قصر جان روشنیست[EOS]',
#  '[BOM]گرچه از میری ورا آوازه ایست[BOM]همچو درویشان مر او را کازه ایست[EOS]',
#  '[BOM]ای برادر چون ببینی قصر او[BOM]چونک در چشم دلت رستست مو[EOS]',
#  '[BOM]چشم دل از مو و علت پاک آر[BOM]وانگه آن دیدار قصرش چشم دار[EOS]',
#  '[BOM]هر که را هست از هوسها جان پاک[BOM]زود بیند حضرت و ایوان پاک[EOS]',
#  '[BOM]چون محمد پاک شد زین نار و دود[BOM]هر کجا رو کرد وجه الله بود[EOS]',
#  '[BOM]چون رفیقی وسوسه بدخواه را[BOM]کی بدانی ثم وجه الله را[EOS]',
#  '[BOM]هر که را باشد ز سینه فتح باب[BOM]بیند او بر چرخ دل صد آفتاب[EOS]',
#  '[BOM]حق پدیدست از میان دیگران[BOM]همچو ماه اندر میان اختران[EOS]',
#  '[BOM]دو سر انگشت بر دو چشم نه[BOM]هیچ بینی از جهان انصاف ده[EOS]',
#  '[BOM]گر نبینی این جهان معدوم نیست[BOM]عیب جز ز انگشت نفس شوم نیست[EOS]',
#  '[BOM]تو ز چشم انگشت را بر دار هین[BOM]وانگهانی هرچه می خواهی ببین[EOS]',
#  '[BOM]نوح را گفتند امت کو ثواب[BOM]گفت او زان سوی واستغشوا ثیاب[EOS]',
#  '[BOM]رو و سر در جامه ها پیچیده اید[BOM]لاجرم با دیده و نادیده اید[EOS]',
#  '[BOM]آدمی دیدست و باقی پوستست[BOM]دید آنست آن که دید دوستست[EOS]',
#  '[BOM]چونک دید دوست نبود کور به[BOM]دوست کو باقی نباشد دور به[EOS]',
#  '[BOM]چون رسول روم این الفاظ تر[BOM]در سماع آورد شد مشتاق تر[EOS]',
#  '[BOM]دیده را بر جستن عمر گماشت[BOM]رخت را و اسپ را ضایع گذاشت[EOS]',
#  '[BOM]هر طرف اندر پی آن مرد کار[BOM]می شدی پرسان او دیوانه وار[EOS]',
#  '[BOM]کین چنین مردی بود اندر جهان[BOM]وز جهان مانند جان باشد نهان[EOS]',
#  '[BOM]جست او را تاش چون بنده بود[BOM]لاجرم جوینده یابنده بود[EOS]',
#  '[BOM]دید اعرابی زنی او را دخیل[BOM]گفت عمر نک به زیر آن نخیل[EOS]',
#  '[BOM]زیر خرمابن ز خلقان او جدا[BOM]زیر سایه خفته بین سایه خدا[EOS]',
#  '[BOM]آمد او آنجا و از دور ایستاد[BOM]مر عمر را دید و در لرز اوفتاد[EOS]',
#  '[BOM]هیبتی زان خفته آمد بر رسول[BOM]حالتی خوش کرد بر جانش نزول[EOS]',
#  '[BOM]مهر و هیبت هست ضد همدگر[BOM]این دو ضد را دید جمع اندر جگر[EOS]',
#  '[BOM]گفت با خود من شهان را دیده ام[BOM]پیش سلطانان مه و بگزیده ام[EOS]',
#  '[BOM]از شهانم هیبت و ترسی نبود[BOM]هیبت این مرد هوشم را ربود[EOS]',
#  '[BOM]رفته ام در بیشه شیر و پلنگ[BOM]روی من زیشان نگردانید رنگ[EOS]',
#  '[BOM]بس شدستم در مصاف و کارزار[BOM]همچو شیر آن دم که باشد کارزار[EOS]',
#  '[BOM]بس که خوردم بس زدم زخم گران[BOM]دل قوی تر بوده ام از دیگران[EOS]',
#  '[BOM]بی سلاح این مرد خفته بر زمین[BOM]من به هفت اندام لرزان چیست این[EOS]',
#  '[BOM]هیبت حقست این از خلق نیست[BOM]هیبت این مرد صاحب دلق نیست[EOS]',
#  '[BOM]هر که ترسید از حق او تقوی گزید[BOM]ترسد از وی جن و انس و هر که دید[EOS]',
#  '[BOM]اندرین فکرت به حرمت دست بست[BOM]بعد یک ساعت عمر از خواب جست[EOS]',
#  '[BOM]کرد خدمت مر عمر را و سلام[BOM]گفت پیغامبر سلام آنگه کلام[EOS]',
#  '[BOM]پس علیکش گفت و او را پیش خواند[BOM]ایمنش کرد و به پیش خود نشاند[EOS]',
#  '[BOM]لاتخافوا هست نزل خایفان[BOM]هست در خور از برای خایف آن[EOS]',
#  '[BOM]هر که ترسد مر ورا ایمن کنند[BOM]مر دل ترسنده را ساکن کنند[EOS]',
#  '[BOM]آنک خوفش نیست چون گویی مترس[BOM]درس چه دهی نیست او محتاج درس[EOS]',
#  '[BOM]آن دل از جا رفته را دلشاد کرد[BOM]خاطر ویرانش را آباد کرد[EOS]',
#  '[BOM]بعد از آن گفتش سخنهای دقیق[BOM]وز صفات پاک حق نعم الرفیق[EOS]',
#  '[BOM]وز نوازشهای حق ابدال را[BOM]تا بداند او مقام و حال را[EOS]',
#  '[BOM]حال چون جلوه ست زان زیبا عروس[BOM]وین مقام آن خلوت آمد با عروس[EOS]',
#  '[BOM]جلوه بیند شاه و غیر شاه نیز[BOM]وقت خلوت نیست جز شاه عزیز[EOS]',
#  '[BOM]جلوه کرده خاص و عامان را عروس[BOM]خلوت اندر شاه باشد با عروس[EOS]',
#  '[BOM]هست بسیار اهل حال از صوفیان[BOM]نادرست اهل مقام اندر میان[EOS]',
#  '[BOM]از منازلهای جانش یاد داد[BOM]وز سفرهای روانش یاد داد[EOS]',
#  '[BOM]وز زمانی کز زمان خالی بدست[BOM]وز مقام قدس که اجلالی بدست[EOS]',
#  '[BOM]وز هوایی کاندرو سیمرغ روح[BOM]پیش ازین دیدست پرواز و فتوح[EOS]',
#  '[BOM]هر یکی پروازش از آفاق بیش[BOM]وز امید و نهمت مشتاق بیش[EOS]',
#  '[BOM]چون عمر اغیاررو را یار یافت[BOM]جان او را طالب اسرار یافت[EOS]',
#  '[BOM]شیخ کامل بود و طالب مشتهی[BOM]مرد چابک بود و مرکب درگهی[EOS]',
#  '[BOM]دید آن مرشد که او ارشاد داشت[BOM]تخم پاک اندر زمین پاک کاشت[EOS]',
#  '[BOM]مرد گفتش کای امیرالمومنین[BOM]جان ز بالا چون در آمد در زمین[EOS]',
#  '[BOM]مرغ بی اندازه چون شد در قفس[BOM]گفت حق بر جان فسون خواند و قصص[EOS]',
#  '[BOM]بر عدمها کان ندارد چشم و گوش[BOM]چون فسون خواند همی آید به جوش[EOS]',
#  '[BOM]از فسون او عدمها زود زود[BOM]خوش معلق می زند سوی وجود[EOS]',
#  '[BOM]باز بر موجود افسونی چو خواند[BOM]زو دو اسپه در عدم موجود راند[EOS]',
#  '[BOM]گفت در گوش گل و خندانش کرد[BOM]گفت با سنگ و عقیق کانش کرد[EOS]',
#  '[BOM]گفت با جسم آیتی تا جان شد او[BOM]گفت با خورشید تا رخشان شد او[EOS]',
#  '[BOM]باز در گوشش دمد نکته مخوف[BOM]در رخ خورشید افتد صد کسوف[EOS]',
#  '[BOM]تا به گوش ابر آن گویا چه خواند[BOM]کو چو مشک از دیده خود اشک راند[EOS]',
#  '[BOM]تا به گوش خاک حق چه خوانده است[BOM]کو مراقب گشت و خامش مانده است[EOS]',
#  '[BOM]در تردد هر که او آشفته است[BOM]حق به گوش او معما گفته است[EOS]',
#  '[BOM]تا کند محبوسش اندر دو گمان[BOM]آن کنم آن گفت یا خود ضد آن[EOS]',
#  '[BOM]هم ز حق ترجیح یابد یک طرف[BOM]زان دو یک را برگزیند زان کنف[EOS]',
#  '[BOM]گر نخواهی در تردد هوش جان[BOM]کم فشار این پنبه اندر گوش جان[EOS]',
#  '[BOM]تا کنی فهم آن معماهاش را[BOM]تا کنی ادراک رمز و فاش را[EOS]',
#  '[BOM]پس محل وحی گردد گوش جان[BOM]وحی چه بود گفتنی از حس نهان[EOS]',
#  '[BOM]گوش جان و چشم جان جز این حس است[BOM]گوش عقل و گوش ظن زین مفلس است[EOS]',
#  '[BOM]لفظ جبرم عشق را بی صبر کرد[BOM]وانک عاشق نیست حبس جبر کرد[EOS]',
#  '[BOM]این معیت با حقست و جبر نیست[BOM]این تجلی مه است این ابر نیست[EOS]',
#  '[BOM]ور بود این جبر جبر عامه نیست[BOM]جبر آن اماره خودکامه نیست[EOS]',
#  '[BOM]جبر را ایشان شناسند ای پسر[BOM]که خدا بگشادشان در دل بصر[EOS]',
#  '[BOM]غیب و آینده بریشان گشت فاش[BOM]ذکر ماضی پیش ایشان گشت لاش[EOS]',
#  '[BOM]اختیار و جبر ایشان دیگرست[BOM]قطره ها اندر صدفها گوهرست[EOS]',
#  '[BOM]هست بیرون قطره خرد و بزرگ[BOM]در صدف آن در خردست و سترگ[EOS]',
#  '[BOM]طبع ناف آهوست آن قوم را[BOM]از برون خون و درونشان مشکها[EOS]',
#  '[BOM]تو مگو کین مایه بیرون خون بود[BOM]چون رود در ناف مشکی چون شود[EOS]',
#  '[BOM]تو مگو کین مس برون بد محتقر[BOM]در دل اکسیر چون گیرد گهر[EOS]',
#  '[BOM]اختیار و جبر در تو بد خیال[BOM]چون دریشان رفت شد نور جلال[EOS]',
#  '[BOM]نان چو در سفره ست باشد آن جماد[BOM]در تن مردم شود او روح شاد[EOS]',
#  '[BOM]در دل سفره نگردد مستحیل[BOM]مستحیلش جان کند از سلسبیل[EOS]',
#  '[BOM]قوت جانست این ای راست خوان[BOM]تا چه باشد قوت آن جان جان[EOS]',
#  '[BOM]گوشت پاره آدمی با عقل و جان[BOM]می شکافد کوه را با بحر و کان[EOS]',
#  '[BOM]زور جان کوه کن شق حجر[BOM]زور جان جان در انشق القمر[EOS]',
#  '[BOM]گر گشاید دل سر انبان راز[BOM]جان به سوی عرش سازد ترک تاز[EOS]',
#  '[BOM]کرد حق و کرد ما هر دو ببین[BOM]کرد ما را هست دان پیداست این[EOS]',
#  '[BOM]گر نباشد فعل خلق اندر میان[BOM]پس مگو کس را چرا کردی چنان[EOS]',
#  '[BOM]خلق حق افعال ما را موجدست[BOM]فعل ما آثار خلق ایزدست[EOS]',
#  '[BOM]ناطقی یا حرف بیند یا غرض[BOM]کی شود یک دم محیط دو عرض[EOS]',
#  '[BOM]گر به معنی رفت شد غافل ز حرف[BOM]پیش و پس یک دم نبیند هیچ طرف[EOS]',
#  '[BOM]آن زمان که پیش بینی آن زمان[BOM]تو پس خود کی ببینی این بدان[EOS]',
#  '[BOM]چون محیط حرف و معنی نیست جان[BOM]چون بود جان خالق این هر دوان[EOS]',
#  '[BOM]حق محیط جمله آمد ای پسر[BOM]وا ندارد کارش از کار دگر[EOS]',
#  '[BOM]گفت شیطان که بما اغویتنی[BOM]کرد فعل خود نهان دیو دنی[EOS]',
#  '[BOM]گفت آدم که ظلمنا نفسنا[BOM]او ز فعل حق نبد غافل چو ما[EOS]',
#  '[BOM]در گنه او از ادب پنهانش کرد[BOM]زان گنه بر خود زدن او بر بخورد[EOS]',
#  '[BOM]بعد توبه گفتش ای آدم نه من[BOM]آفریدم در تو آن جرم و محن[EOS]',
#  '[BOM]نه که تقدیر و قضای من بد آن[BOM]چون به وقت عذر کردی آن نهان[EOS]',
#  '[BOM]گفت ترسیدم ادب نگذاشتم[BOM]گفت هم من پاس آنت داشتم[EOS]',
#  '[BOM]هر که آرد حرمت او حرمت برد[BOM]هر که آرد قند لوزینه خورد[EOS]']

# %%
all_tokens_np.shape
# Out:
# (53833,)

# %%
tokenizer.decode([    7 , 6416  ,  54  ,1402  , 129 , 1994  ,  52 ,  124   ,  7  ,  50  ,2625  ,  60,
  2427 ,   52 ,  124  ,   9  ,   7  , 999  , 121 ,  123 ,   72 ,  285,  4409,    82,
    43 ,  102   ,  7   , 46 ,17961,    73 ,  428,    45  , 419  ,  43 ,16910,    82,
    43,   102   ,  9   ,  7 , 1085 , 1908 , 1174  ,  82  ,1174    ,82,    50 , 4102,
     7 ,   72 , 2399 , 1174  , 562 , 5901 ])
# Out:
# '[BOM] بشنو این نی چون شکایت می کند[BOM] از جداییها حکایت می کند[EOS][BOM] کز نیستان تا مرا ببریده اند[BOM] در نفیرم مرد و زن نالیده اند[EOS][BOM] سینه خواهم شرحه شرحه از فراق[BOM] تا بگویم شرح درد اشتیاق'

# %%
 من آن مرغ غزل خوانم آخر های دری[BOM] مرا او بنی[BOM] خست در کار ما دل حافظ[BOM] می‌کنم[EOS][BOM] برو دل که بگونه بر اک کور باده در طلبه درآب دده درونمان و[BOM] تا در طلب هر کسی دری تا در آن که درو

# %%
all_tokens_np[0:100000]
# Out:
# array([   7, 1582,   43, ...,    0,  157,  890], dtype=uint16)

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1

# %%
pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.7.0

# %%
# !rm -r data_val*

# %%
docs['text'].to_numpy()
# Out:
# array(['hello i am snana', 'hello how are you', 'oh hello'], dtype=object)

# %%
rank 0 sample 0: روزی در کنار درختی نشسته بودم ش<endoftext|> <|endoftext|>
rank 0 sample 1: روزی در کنار درختی نشسته بودم<یDri<|endoftext|> <|endoftext|> <|endoftext|>و<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>
rank 0 sample 2: روزی در کنار درختی نشسته بودم<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>و<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ش<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ی<|endoftext|>ن<|endoftext|> <|endoftext|> <|endoftext|>ی<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>و<|endoftext|>ه<|endoftext|>م<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ک<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>
rank 0 sample 3: روزی در کنار درختی نشسته بودم<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ی<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ن<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ش<|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|> <|endoftext|>ش<|endoftext|> <|endoftext|> <|endoftext|>ا<|endoftext|>ا<|endoftext|> <|endoftext|>م

# %%
from transformers import AutoConfig, AutoTokenizer, AutoModel, TFAutoModel

# v3.0
model_name_or_path = "HooshvareLab/bert-fa-zwnj-base"
tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/292 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/565 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/426k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/134 [00:00<?, ?B/s]

# %%
tokenizer.tokenize('سلام دوستان من')
# Out:
# ['سلام', 'دوستان', 'من']

# %%
from transformers import pipeline, AutoTokenizer, GPT2LMHeadModel
tokenizer = AutoTokenizer.from_pretrained('bolbolzaban/gpt2-persian')
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/537k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.13M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/399 [00:00<?, ?B/s]

# %%
from transformers import pipeline, AutoTokenizer, GPT2LMHeadModel
tokenizer = AutoTokenizer.from_pretrained('flax-community/gpt2-medium-persian')
tokenizer.tokenize('سلام دوستان من')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/921 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.41M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.33M [00:00<?, ?B/s]
# ['Ø³ÙĦØ§Ùħ', 'ĠØ¯ÙĪØ³ØªØ§ÙĨ', 'ĠÙħÙĨ']

# %%
fp = open('text.txt')
data = fp.read()

# %%
data[280:1000]
# Out:
# ' گاهی دیگران سرنوشت را تعیین می کنند. زمانی که به گذشته باز می گردیم به کنیم که با یک اتفاقساده، دیگرالحظاتی برخورد می ن توانسته اند زندگیمان را دگرگون کنند.  این داستانی است از یک زندگی.  مسافرین محترم ورود شما را به خاک ایران خوش آمد می گویم. ساعت 02:02  دقیقه به وقت تهران است. هوا هفده درجهباالی صفر و بارانیست. امیدوارم از پرواز لذت برده باشید. لطفت در جای خود نشسته و کمربند را ببندید. آرزوی دیدار مجدد شما را داریم.  هومن- دیگه پامو تو این بشقاب پرنده نمی ذارم. اسمشو باید می ذاشتند شرکت هواپیمایی اتو معلق! خیلی خوب ازمون  پذیرایی کردند که آرزوی دیدار مجددمون را هم دارن؟!  من- چی می گی هومن؟ چرا غر می زنی؟  هومن- می گن داریم سقوط می کنیم. خلبان یادش رفته چرخهای هواپیما رو سوار هواپیما کند.  هر بدی و خوبی از م'

# %%
#data_split = data[280:].split(' ')
tokenizer.tokenize(data)

# %%
sorted(list(set(data_split)))

# %%
# importing all the required modules
import PyPDF2

# creating a pdf reader object
reader = PyPDF2.PdfReader('/content/shahnameh.pdf')

# print the number of pages in pdf file
print(len(reader.pages))

# print the text of the first page
page = reader.pages[32].extract_text()
page.split('\n')
# Out:
# 1973
# ['3کنون ای خردمند وصف خرد ',
#  'خرد را و جان را که یارد ستودسه پاس تو چشم است وگوش و زباننخست آفرینش خرد را شناسخرد چشم جانست چون بنگریازویی به هر دو سرای ارجمندهشیوار دیوانه خواند وراکسی کو خرد را ندارد ز پیشچه گفت آن خردمند مرد خردخرد تیره و مرد روشن روانازو شادمانی وزویت غمیستخرد رهنمای و خرد دلگشایخرد بهتر از هر چه ایزد بدادکنون تا چه داری بیار از خرد ',
#  'حکیما چو کس نیست گفتن چه سود ',
#  'تویی کرده ی کردگار جهان ',
#  'خرد دست گیرد به هر دو سرایستایش خرد را به از راه دادکه گوش نیوشنده زو برخوردبدین جایگه گفتن اندرخورداز آغاز باید که دانی درستچو دیدار یابی به شاخ سخنز هر دانشی چون سخن بشنویبه گفتار دانندگان راه جوی ',
#  'وزویت فزونی وزویت کمیست ',
#  'نباشد همی شادمان یک زمان ',
#  'دلش گردد از کرده ی خویش ریشکه دانا ز گفتار از برخورد ',
#  'تو بی چشم شادان جهان نسپریگسسته خرد پای دارد ببندهمان خویش بیگانه داند ورا ',
#  'کزین سه رسد نیک و بد بی گماننگهبان جانست و آن سه پاس ',
#  'و گر من ستایم که یارد شنود ',
#  'ازین پس بگو کافرینش چه بود ',
#  ' سر مایه ی گوهران از نخستبدانی که دانش نیابد به مناز آموختن یک زمان نغنویبه گیتی بپوی و به هر کس بگویببینی همی آشکار و نهان ',
#  'گفتار اندر ستایش خرد ',
#  ' ',
#  'گفتار اندر آفرینش جهان www.takbook.com']

# %%
from io import StringIO

# Read each line of the PDF
pdfContent = StringIO(getPDFContent("/content/shahnameh.pdf").encode("ascii", "ignore"))
for line in pdfContent:
    print(line.strip())
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-1a29804a3408> in <cell line: 4>()
#       2
#       3 # Read each line of the PDF
# ----> 4 pdfContent = StringIO(getPDFContent("/content/shahnameh.pdf").encode("ascii", "ignore"))
#       5 for line in pdfContent:
#       6     print(line.strip())
#
# NameError: name 'getPDFContent' is not defined

# %%
# !pip install pdfquery
# Out:
# Collecting pdfquery
#   Downloading pdfquery-0.4.3.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cssselect>=0.7.1 (from pdfquery)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from pdfquery) (5.2.0)
# Requirement already satisfied: lxml>=3.0 in /usr/local/lib/python3.10/dist-packages (from pdfquery) (4.9.4)
# Collecting pdfminer.six (from pdfquery)
#   Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 73.3 MB/s eta 0:00:00
# Collecting pyquery>=1.2.2 (from pdfquery)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting roman>=1.4.0 (from pdfquery)
#   Downloading roman-4.2-py3-none-any.whl (5.5 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pdfquery) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->pdfquery) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->pdfquery) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pdfquery) (2.22)
# Building wheels for collected packages: pdfquery
#   Building wheel for pdfquery (setup.py) ... done
#   Created wheel for pdfquery: filename=pdfquery-0.4.3-py3-none-any.whl size=16780 sha256=4cacbdd0adff270ff9ab8c7ff97ef5bbba56d5cce091cd07ec47617bf6ec9008
#   Stored in directory: /root/.cache/pip/wheels/98/a2/41/ca6652543d0fa5762560eaaf0f620a5d6341ec0b9e60996d16
# Successfully built pdfquery
# Installing collected packages: roman, cssselect, pyquery, pdfminer.six, pdfquery
# Successfully installed cssselect-1.2.0 pdfminer.six-20240706 pdfquery-0.4.3 pyquery-2.0.0 roman-4.2

# %%
from pdfquery import PDFQuery

pdf = PDFQuery('/content/shahnameh.pdf')
pdf.load()

# Use CSS-like selectors to locate the elements
text_elements = pdf.pq('LTTextLineHorizontal')

# Extract the text from the elements
text = [t.text for t in text_elements]

print(text)

# %%
|pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2

p = '/content/shahnameh.pdf'
reader = PyPDF2.PdfReader('/content/shahnameh.pdf')
reader.getPage(35).extractText() + "\n"
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# <ipython-input-17-5236977e8af0> in <cell line: 5>()
#       3 p = '/content/shahnameh.pdf'
#       4 reader = PyPDF2.PdfReader('/content/shahnameh.pdf')
# ----> 5 reader.getPage(35).extractText() + "\n"
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_reader.py in getPage(self, pageNumber)
#     474             Use :code:`reader.pages[page_number]` instead.
#     475         """
# --> 476         deprecation_with_replacement(
#     477             "reader.getPage(pageNumber)", "reader.pages[page_number]", "3.0.0"
#     478         )
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py in deprecation_with_replacement(old_name, new_name, removed_in)
#     367     Raise an exception that a feature was already removed, but has a replacement.
#     368     """
# --> 369     deprecation(DEPR_MSG_HAPPENED.format(old_name, removed_in, new_name))
#     370
#     371
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py in deprecation(msg)
#     349
#     350 def deprecation(msg: str) -> None:
# --> 351     raise DeprecationError(msg)
#     352
#     353
#
# DeprecationError: reader.getPage(pageNumber) is deprecated and was removed in PyPDF2 3.0.0. Use reader.pages[page_number] instead.

# %%
pip install StringIO
# Out:
# ERROR: Could not find a version that satisfies the requirement StringIO (from versions: none)
# ERROR: No matching distribution found for StringIO

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
tokenizer.encode('سلام وقت به خیر', add_special_tokens=True)
# Out:
# [5, 1533, 446, 48, 1438, 3]

# %%
    additional_special_tokens=['<A>', '<B>', '<C>']


special_tokens_dict = {'[BOM]':''}

num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)
print('We have added', num_added_toks, 'tokens')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-24d4fbde0eba> in <cell line: 3>()
#       1 special_tokens_dict = {'[BOM]':''}
#       2
# ----> 3 num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)
#       4 print('We have added', num_added_toks, 'tokens')
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in add_special_tokens(self, special_tokens_dict, replace_additional_special_tokens)
#     945         added_tokens = []
#     946         for key, value in special_tokens_dict.items():
# --> 947             assert key in self.SPECIAL_TOKENS_ATTRIBUTES, f"Key {key} is not a special token"
#     948
#     949             if self.verbose:
#
# AssertionError: Key [BOM] is not a special token

# %%
from transformers import pipeline, AutoTokenizer, GPT2LMHeadModel
tokenizer = AutoTokenizer.from_pretrained('bolbolzaban/gpt2-persian')
tokenizer.encode('تمام امروز خود را بدادم به دل [BOM] کنون ای خردمند وصف خرد', add_special_tokens=False), tokenizer.tokenize('کنون ای خردمند وصف خرد')
# Out:
# ([254, 245, 67, 53, 8915, 73, 48, 128, 7, 1641, 213, 7770, 3413, 1716],
#  ['▁کنون', '▁ای', '▁خردمند', '▁وصف', '▁خرد'])

# %%
tokenizer.decode([254, 245, 67, 53, 8915, 73, 48, 128, 7, 1641, 213, 7770, 3413, 1716])
# Out:
# 'تمام امروز خود را بدادم به دل[BOM] کنون ای خردمند وصف خرد'

# %%
fp = open('/content/Hafezfull.txt')
docs = fp.readlines()
lines = []
for i in range(len(docs)-1):
  mesr1 = docs[i].replace('\n', '')
  mesr2 = docs[i+1].replace('\n', '')
  line = '[BOM]'+ mesr1 + '[BOM]' + mesr2+ '[EOS]'
  lines.append(line)

# %%
len(lines)
# Out:
# 8383
